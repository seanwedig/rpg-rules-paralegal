# %%
pdf_path = "./data/SRD_CC_v5.1.pdf"

# %%
from pprint import pprint

# %% [markdown]
# # PyMuPDF

# %%
import fitz

doc = fitz.open(pdf_path) # open a document

# %%
page = doc[3]
page
# Out:
# page 3 of ./data/SRD_CC_v5.1.pdf

# %%
import re

def strip_boilerplate(text: str) -> str:
    text = text
    page_boilerplate = 'System\xa0Reference\xa0Document\xa05.1\xa0\n\xa0 \d+\xa0\n'
    text = re.sub(page_boilerplate, '', text)
    text = re.sub('System\s+Reference\s+Document\s+5.1\s+\d+\s+', '', text)
    
    error_note = 'If you note any errors in this document, please let us know by \nemailing askdnd@wizards.com. \n'
    if error_note in text:
        text = text.replace(error_note, '')
    
    return text

# %%
def clean_page_contents(contents: str) -> str:
    contents = contents.replace('\t\r \xa0', ' ')
    contents = strip_boilerplate(contents)
    return contents

# %%
# collect all text blocks on all pages, and sort them by length (to see if we can find headers)

all_blocks = []

for i, page in enumerate(doc):
    blocks = page.get_text_blocks()
    for block in page.get_text_blocks():
        (x0, y0, x1, y1, block_text, block_no, block_type) = block

        block_content = clean_page_contents(block_text)
        if (block_content == ''):
            continue
        all_blocks.append((x0, y0, x1, y1, block_content, block_no, block_type))

len(all_blocks)
# Out:
# 11166

# %%
import re
import math


def is_header(block) -> bool:
    (x0, y0, x1, y1, text, block_no, block_type) = block

    HEADER_LEFT_COLUMN_X = 57.599998474121094
    HEADER_RIGHT_COLUMN_X = 328.55999755859375
    TOLERANCE = 0.001

    if not math.isclose(x0, HEADER_LEFT_COLUMN_X, rel_tol=TOLERANCE) and not math.isclose(x0, HEADER_RIGHT_COLUMN_X, rel_tol=TOLERANCE):
        return False

    # if the first character is capital, and the line length is less than 20, and it ends in \n
    if len(text) == 0:
        return False
    if len(text) > 40:
        return False
    if text[-1] != '\n':
        return False
    if text[0].isupper():
        return True
    
    return False

headers = [block[4] for block in all_blocks if is_header(block)]

from pprint import pprint
pprint(headers)
# Out:
# ['Legal\xa0Information\xa0\n',
#  'Races \nRacial Traits \n',
#  'Dwarf \nDwarf Traits \n',
#  'Elf \nElf Traits \n',
#  'Halfling \nHalfling Traits \n',
#  'Human \nHuman Traits \n',
#  'Dragonborn \nDragonborn Traits \n',
#  'Draconic Ancestry \n',
#  'Dragon \nDamage Type \nBreath Weapon \n',
#  'Gold \nFire \n15 ft. cone (Dex. save) \n',
#  'Green \nPoison \n15 ft. cone (Con. save) \n',
#  'Red \nFire \n15 ft. cone (Dex. save) \n',
#  'Silver \nCold \n15 ft. cone (Con. save) \n',
#  'White \nCold \n15 ft. cone (Con. save) \n',
#  'Gnome \nGnome Traits \n',
#  'Half-Elf \nHalf-Elf Traits \n',
#  'Half-Orc \nHalf-Orc Traits \n',
#  'Tiefling \nTiefling Traits \n',
#  'Barbarian \n',
#  'The Barbarian \n',
#  'Level \n',
#  'Rage \n',
#  'Unarmored Defense \n',
#  'Reckless Attack \n',
#  'Danger Sense \n',
#  'Primal Path \n',
#  'Ability Score Improvement \n',
#  'Extra Attack \n',
#  'Fast Movement \n',
#  'Feral Instinct \n',
#  'Brutal Critical \n',
#  'Relentless Rage \n',
#  'Persistent Rage \n',
#  'Indomitable Might \n',
#  'Primal Champion \n',
#  'Path of the Berserker \n',
#  'Bard \n',
#  'Proficiencies \nArmor: Light armor \n',
#  'The Bard \n',
#  'Spellcasting \n',
#  'Bardic Inspiration \n',
#  'Jack of All Trades \n',
#  'Song of Rest \n',
#  'Bard College \n',
#  'Expertise \n',
#  'Ability Score Improvement \n',
#  'Font of Inspiration \n',
#  'Countercharm \n',
#  'Magical Secrets \n',
#  'Superior Inspiration \n',
#  'College of Lore \n',
#  'Cleric \n',
#  'The Cleric \n',
#  'Spellcasting \n',
#  'Divine Domain \n',
#  'Channel Divinity \n',
#  'Ability Score Improvement \n',
#  'Destroy Undead \n',
#  'Destroy Undead \n',
#  'Divine Intervention \n',
#  'Life Domain \n',
#  'Life Domain Spells \n',
#  'Cleric Level \nSpells \n',
#  'Druid \n',
#  'The Druid \n',
#  'Druidic \n',
#  'Spellcasting \n',
#  'Wild Shape \n',
#  'Beast Shapes \n',
#  'Level \n',
#  'Druid Circle \n',
#  'Ability Score Improvement \n',
#  'Timeless Body \n',
#  'Beast Spells \n',
#  'Archdruid \n',
#  'Circle of the Land \n',
#  'Arctic \n',
#  'Druid Level \nCircle Spells \n',
#  'Coast \n',
#  'Druid Level \nCircle Spells \n',
#  'Desert \n',
#  'Druid Level \nCircle Spells \n',
#  'Forest \n',
#  'Druid Level \nCircle Spells \n',
#  'Grassland \n',
#  'Druid Level \nCircle Spells \n',
#  'Mountain \n',
#  'Druid Level \nCircle Spells \n',
#  'Swamp \n',
#  'Druid Level \nCircle Spells \n',
#  'Sacred Plants and Wood \n',
#  'Druids and the Gods \n',
#  'Fighter \n',
#  'The Fighter \n',
#  'Level \n',
#  'Fighting Style \n',
#  'Second Wind \n',
#  'Action Surge \n',
#  'Martial Archetype \n',
#  'Ability Score Improvement \n',
#  'Extra Attack \n',
#  'Indomitable \n',
#  'Champion \n',
#  'Monk \n',
#  'Proficiencies \nArmor: None \n',
#  'The Monk \n',
#  'Unarmored Defense \n',
#  'Martial Arts \n',
#  'Ki \n',
#  'Unarmored Movement \n',
#  'Monastic Tradition \n',
#  'Deflect Missiles \n',
#  'Ability Score Improvement \n',
#  'Slow Fall \n',
#  'Extra Attack \n',
#  'Stunning Strike \n',
#  'Ki-Empowered Strikes \n',
#  'Evasion \n',
#  'Stillness of Mind \n',
#  'Purity of Body \n',
#  'Tongue of the Sun and Moon \n',
#  'Diamond Soul \n',
#  'Timeless Body \n',
#  'Empty Body \n',
#  'Perfect Self \n',
#  'Way of the Open Hand \n',
#  'Paladin \n',
#  'The Paladin \n',
#  'Divine Sense \n',
#  'Lay on Hands \n',
#  'Fighting Style \n',
#  'Spellcasting \n',
#  'Divine Smite \n',
#  'Divine Health \n',
#  'Sacred Oath \n',
#  'Ability Score Improvement \n',
#  'Extra Attack \n',
#  'Aura of Protection \n',
#  'Aura of Courage \n',
#  'Improved Divine Smite \n',
#  'Cleansing Touch \n',
#  'Oath of Devotion \n',
#  'Oath of Devotion Spells \n',
#  'Breaking Your Oath \n',
#  'Ranger \n',
#  'The Ranger \n',
#  'Favored Enemy \n',
#  'Natural Explorer \n',
#  'Fighting Style \n',
#  'Spellcasting \n',
#  'Ranger Archetype \n',
#  'Primeval Awareness \n',
#  'Ability Score Improvement \n',
#  'Extra Attack \n',
#  'Land’s Stride \n',
#  'Hide in Plain Sight \n',
#  'Vanish \n',
#  'Feral Senses \n',
#  'Foe Slayer \n',
#  'Hunter \n',
#  'Rogue \n',
#  'The Rogue \n',
#  'Level \n',
#  'Expertise \n',
#  'Sneak Attack \n',
#  'Thieves’ Cant \n',
#  'Cunning Action \n',
#  'Roguish Archetype \n',
#  'Ability Score Improvement \n',
#  'Uncanny Dodge \n',
#  'Evasion \n',
#  'Reliable Talent \n',
#  'Blindsense \n',
#  'Slippery Mind \n',
#  'Elusive \n',
#  'Stroke of Luck \n',
#  'Thief \n',
#  'Sorcerer \n',
#  'Proficiencies \nArmor: None \n',
#  'The Sorcerer \n',
#  'Spellcasting \n',
#  'Sorcerous Origin \n',
#  'Font of Magic \n',
#  'Creating Spell Slots \n',
#  'Spell Slot \n',
#  'Metamagic \n',
#  'Ability Score Improvement \n',
#  'Sorcerous Restoration \n',
#  'Draconic Bloodline \n',
#  'Draconic Ancestry \n',
#  'Dragon \nDamage Type \n',
#  'Black \nAcid \n',
#  'Blue \nLightning \n',
#  'Brass \nFire \n',
#  'Bronze \nLightning \n',
#  'Copper \nAcid \n',
#  'Gold \nFire \n',
#  'Green \nPoison \n',
#  'Red \nFire \n',
#  'Silver \nCold \n',
#  'White \nCold \n',
#  'Warlock \n',
#  'Proficiencies \nArmor: Light armor \n',
#  'The Warlock \n',
#  'Level \n',
#  'Otherworldly Patron \n',
#  'Pact Magic \n',
#  'Eldritch Invocations \n',
#  'Pact Boon \n',
#  'Ability Score Improvement \n',
#  'Mystic Arcanum \n',
#  'Eldritch Master \n',
#  'Dreadful Word \nPrerequisite: 7th level \n',
#  'Mire the Mind \nPrerequisite: 5th level \n',
#  'Witch Sight \nPrerequisite: 15th level \n',
#  'The Fiend \n',
#  'Fiend Expanded Spells \n',
#  'Spell Level \nSpells \n',
#  'Your Pact Boon \n',
#  'Wizard \n',
#  'Proficiencies \nArmor: None \n',
#  'The Wizard \n',
#  'Spellcasting \n',
#  'Arcane Recovery \n',
#  'Arcane Tradition \n',
#  'Ability Score Improvement \n',
#  'Spell Mastery \n',
#  'Signature Spells \n',
#  'School of Evocation \n',
#  'Your Spellbook \n',
#  'Beyond 1st Level \n',
#  'Character Advancement \n',
#  'Prerequisites \n',
#  'Multiclassing Prerequisites \n',
#  'Class \nAbility Score Minimum \n',
#  'Barbarian \nStrength 13 \n',
#  'Bard \nCharisma 13 \n',
#  'Cleric \nWisdom 13 \n',
#  'Druid \nWisdom 13 \n',
#  'Fighter \nStrength 13 or Dexterity 13 \n',
#  'Monk \nDexterity 13 and Wisdom 13 \n',
#  'Paladin \nStrength 13 and Charisma 13 \n',
#  'Ranger \nDexterity 13 and Wisdom 13 \n',
#  'Rogue \nDexterity 13 \n',
#  'Sorcerer \nCharisma 13 \n',
#  'Warlock \nCharisma 13 \n',
#  'Wizard \nIntelligence 13 \n',
#  'Experience Points \n',
#  'Hit Points and Hit Dice \n',
#  'Proficiency Bonus \n',
#  'Proficiencies \n',
#  'Multiclassing Proficiencies \n',
#  'Class \nProficiencies Gained \n',
#  'Monk \nSimple weapons, shortswords \n',
#  'Sorcerer \n— \n',
#  'Warlock \nLight armor, simple weapons \n',
#  'Wizard \n— \n',
#  'Class Features \n',
#  'Standard Languages \n',
#  'Language \nTypical Speakers \nScript \n',
#  'Common \nHumans \nCommon \n',
#  'Dwarvish \nDwarves \nDwarvish \n',
#  'Elvish \nElves \nElvish \n',
#  'Giant \nOgres, giants \nDwarvish \n',
#  'Gnomish \nGnomes \nDwarvish \n',
#  'Goblin \nGoblinoids \nDwarvish \n',
#  'Halfling \nHalflings \nCommon \n',
#  'Orc \nOrcs \nDwarvish \n',
#  'Exotic Languages \n',
#  'Language \nTypical Speakers \nScript \n',
#  'Abyssal \nDemons \nInfernal \n',
#  'Celestial \nCelestials \nCelestial \n',
#  'Deep Speech \nAboleths,  cloakers \n— \n',
#  'Infernal \nDevils \nInfernal \n',
#  'Primordial \nElementals \nDwarvish \n',
#  'Sylvan \nFey creatures \nElvish \n',
#  'Gaining Inspiration \n',
#  'Using Inspiration \n',
#  'Acolyte \n',
#  'Equipment \n',
#  'Standard Exchange Rates \n',
#  'Coin \nCP \nSP \nEP \nGP \nPP \n',
#  'Silver (sp) \n10 \n1 \n1/5 \n1/10 \n1/100 \n',
#  'Electrum (ep) \n50 \n5 \n1 \n1/2 \n1/20 \n',
#  'Gold (gp) \n100 \n10 \n2 \n1 \n1/10 \n',
#  'Platinum (pp) \n1,000 \n100 \n20 \n10 \n1 \n',
#  'Light Armor \n',
#  'Medium Armor \n',
#  'Heavy Armor \n',
#  'Armor \n',
#  'Light Armor \n',
#  'Medium Armor \n',
#  'Heavy Armor \n',
#  'Shield \n',
#  'Getting Into and Out of Armor \n',
#  'Donning and Doffing Armor \n',
#  'Category \nDon \nDoff \n',
#  'Light Armor \n1 minute \n1 minute \n',
#  'Medium Armor \n5 minutes \n1 minute \n',
#  'Heavy Armor \n10 minutes \n5 minutes \n',
#  'Shield \n1 action \n1 action \n',
#  'Weapon Proficiency \n',
#  'Weapon Properties \n',
#  'Weapons \n',
#  'Name \nCost \nDamage \nWeight \nProperties \n',
#  'Simple Melee Weapons \n',
#  'Simple Ranged Weapons \n',
#  'Martial Melee Weapons \n',
#  'Martial Ranged Weapons \n',
#  'Adventuring Gear \n',
#  'Item \nCost \nWeight \n',
#  'Abacus \n2 gp \n2 lb. \n',
#  'Acid (vial) \n25 gp \n1 lb. \n',
#  'Alchemist’s fire (flask) \n50 gp \n1 lb. \n',
#  'Ammunition \n',
#  'Antitoxin (vial) \n50 gp \n— \n',
#  'Arcane focus \n',
#  'Backpack \n2 gp \n5 lb. \n',
#  'Barrel \n2 gp \n70 lb. \n',
#  'Basket \n4 sp \n2 lb. \n',
#  'Bedroll \n1 gp \n7 lb. \n',
#  'Bell \n1 gp \n— \n',
#  'Blanket \n5 sp \n3 lb. \n',
#  'Block and tackle \n1 gp \n5 lb. \n',
#  'Book \n25 gp \n5 lb. \n',
#  'Bottle, glass \n2 gp \n2 lb. \n',
#  'Bucket \n5 cp \n2 lb. \n',
#  'Caltrops (bag of 20) \n1 gp \n2 lb. \n',
#  'Candle \n1 cp \n— \n',
#  'Case, crossbow bolt \n1 gp \n1 lb. \n',
#  'Case, map or scroll \n1 gp \n1 lb. \n',
#  'Chain (10 feet) \n5 gp \n10 lb. \n',
#  'Chalk (1 piece) \n1 cp \n— \n',
#  'Chest \n5 gp \n25 lb. \n',
#  'Climber’s kit \n25 gp \n12 lb. \n',
#  'Clothes, common \n5 sp \n3 lb. \n',
#  'Clothes, costume \n5 gp \n4 lb. \n',
#  'Clothes, fine \n15 gp \n6 lb. \n',
#  'Clothes, traveler’s \n2 gp \n4 lb. \n',
#  'Component pouch \n25 gp \n2 lb. \n',
#  'Crowbar \n2 gp \n5 lb. \n',
#  'Druidic focus \n',
#  'Fishing tackle \n1 gp \n4 lb. \n',
#  'Flask or tankard \n2 cp \n1 lb. \n',
#  'Grappling hook \n2 gp \n4 lb. \n',
#  'Hammer \n1 gp \n3 lb. \n',
#  'Hammer, sledge \n2 gp \n10 lb. \n',
#  'Healer’s kit \n5 gp \n3 lb. \n',
#  'Holy symbol \n',
#  'Holy water (flask) \n25 gp \n1 lb. \n',
#  'Hourglass \n25 gp \n1 lb. \n',
#  'Hunting trap \n5 gp \n25 lb. \n',
#  'Ink (1 ounce bottle) \n10 gp \n— \n',
#  'Ink pen \n2 cp \n— \n',
#  'Jug or pitcher \n2 cp \n4 lb. \n',
#  'Ladder (10-\xad‐foot) \n1 sp \n25 lb. \n',
#  'Lamp \n5 sp \n1 lb. \n',
#  'Lantern, bullseye \n10 gp \n2 lb. \n',
#  'Lantern, hooded \n5 gp \n2 lb. \n',
#  'Lock \n10 gp \n1 lb. \n',
#  'Magnifying glass \n100 gp \n— \n',
#  'Manacles \n2 gp \n6 lb. \n',
#  'Mess kit \n2 sp \n1 lb. \n',
#  'Mirror, steel \n5 gp \n1/2 lb. \n',
#  'Oil (flask) \n1 sp \n1 lb. \n',
#  'Paper (one sheet) \n2 sp \n— \n',
#  'Parchment (one sheet) \n1 sp \n— \n',
#  'Perfume (vial) \n5 gp \n— \n',
#  'Pick, miner’s \n2 gp \n10 lb. \n',
#  'Piton \n5 cp \n1/4 lb. \n',
#  'Poison, basic (vial) \n100 gp \n— \n',
#  'Pole (10-\xad‐foot) \n5 cp \n7 lb. \n',
#  'Pot, iron \n2 gp \n10 lb. \n',
#  'Potion of healing \n50 gp \n1/2 lb. \n',
#  'Pouch \n5 sp \n1 lb. \n',
#  'Quiver \n1 gp \n1 lb. \n',
#  'Ram, portable \n4 gp \n35 lb. \n',
#  'Rations (1 day) \n5 sp \n2 lb. \n',
#  'Robes \n1 gp \n4 lb. \n',
#  'Rope, hempen (50 feet) \n1 gp \n10 lb. \n',
#  'Rope, silk (50 feet) \n10 gp \n5 lb. \n',
#  'Sack \n1 cp \n1/2 lb. \n',
#  'Scale, merchant’s \n5 gp \n3 lb. \n',
#  'Sealing wax \n5 sp \n— \n',
#  'Shovel \n2 gp \n5 lb. \n',
#  'Signal whistle \n5 cp \n— \n',
#  'Signet ring \n5 gp \n— \n',
#  'Soap \n2 cp \n— \n',
#  'Spellbook \n50 gp \n3 lb. \n',
#  'Spikes, iron (10) \n1 gp \n5 lb. \n',
#  'Spyglass \n1,000 gp \n1 lb. \n',
#  'Tent, two-\xad‐person \n2 gp \n20 lb. \n',
#  'Tinderbox \n5 sp \n1 lb. \n',
#  'Torch \n1 cp \n1 lb. \n',
#  'Vial \n1 gp \n— \n',
#  'Waterskin \n2 sp \n5 lb. (full) \n',
#  'Whetstone \n1 cp \n1 lb. \n',
#  'Container Capacity \n',
#  'Container \nCapacity \n',
#  'Basket \n2 cubic feet/40 pounds of gear \n',
#  'Bottle \n1½ pints liquid \n',
#  'Flask or tankard \n1 pint liquid \n',
#  'Jug or pitcher \n1 gallon liquid \n',
#  'Pot, iron \n1 gallon liquid \n',
#  'Pouch \n1/5 cubic foot/6 pounds of gear \n',
#  'Sack \n1 cubic foot/30 pounds of gear \n',
#  'Vial \n4 ounces liquid \n',
#  'Waterskin \n4 pints liquid \n',
#  'Equipment Packs \n',
#  'Tools \n',
#  'Item \nCost \nWeight \n',
#  'Artisan’s tools \n',
#  'Gaming set \n',
#  'Herbalism kit \n5 gp \n3 lb. \n',
#  'Musical instrument \n',
#  'Navigator’s tools \n25 gp \n2 lb. \n',
#  'Poisoner’s kit \n50 gp \n2 lb. \n',
#  'Thieves’ tools \n25 gp \n1 lb. \n',
#  'Vehicles (land or water) \n* \n* \n',
#  'Mounts and Other Animals \n',
#  'Item \nCost \nSpeed \n',
#  'Camel \n50 gp \n50 ft. \n480 lb. \n',
#  'Donkey or mule \n8 gp \n40 ft. \n420 lb. \n',
#  'Elephant \n200 gp \n40 ft. \n1,320 lb. \n',
#  'Horse, draft \n50 gp \n40 ft. \n540 lb. \n',
#  'Horse, riding \n75 gp \n60 ft. \n480 lb. \n',
#  'Mastiff \n25 gp \n40 ft. \n195 lb. \n',
#  'Pony \n30 gp \n40 ft. \n225 lb. \n',
#  'Warhorse \n400 gp \n60 ft. \n540 lb. \n',
#  'Tack, Harness, and Drawn Vehicles \n',
#  'Item \nCost \nWeight \n',
#  'Barding \n×4 \n×2 \n',
#  'Bit and bridle \n2 gp \n1 lb. \n',
#  'Carriage \n100 gp \n600 lb. \n',
#  'Cart \n15 gp \n200 lb. \n',
#  'Chariot \n250 gp \n100 lb. \n',
#  'Feed (per day) \n5 cp \n10 lb. \n',
#  'Saddle \n',
#  'Saddlebags \n4 gp \n8 lb. \n',
#  'Sled \n20 gp \n300 lb. \n',
#  'Stabling (per day) \n5 sp \n— \n',
#  'Wagon \n35 gp \n400 lb. \n',
#  'Waterborne Vehicles \n',
#  'Item \nCost \nSpeed \n',
#  'Galley \n30,000 gp \n4 mph \n',
#  'Keelboat \n3,000 gp \n1 mph \n',
#  'Longship \n10,000 gp \n3 mph \n',
#  'Rowboat \n50 gp \n1½ mph \n',
#  'Sailing ship \n10,000 gp \n2 mph \n',
#  'Warship \n25,000 gp \n2½ mph \n',
#  'Trade Goods \n',
#  'Cost \nGoods \n',
#  'Lifestyle Expenses \n',
#  'Lifestyle Expenses \n',
#  'Lifestyle \nPrice/Day \n',
#  'Wretched \n— \n',
#  'Squalid \n1 sp \n',
#  'Poor \n2 sp \n',
#  'Modest \n1 gp \n',
#  'Comfortable \n2 gp \n',
#  'Wealthy \n4 gp \n',
#  'Aristocratic \n10 gp minimum \n',
#  'Self-Sufficiency \n',
#  'Food, Drink, and Lodging \n',
#  'Food, Drink, and Lodging \n',
#  'Item \nCost \n',
#  'Ale \n',
#  'Banquet (per person) \n10 gp \n',
#  'Bread, loaf \n2 cp \n',
#  'Cheese, hunk \n1 sp \n',
#  'Inn stay (per day) \n',
#  'Meals (per day) \n',
#  'Meat, chunk \n3 sp \n',
#  'Wine \n',
#  'Services \n',
#  'Services \n',
#  'Service \nPay \n',
#  'Coach cab \n',
#  'Hireling \n',
#  'Messenger \n2 cp per mile \n',
#  'Road or gate toll \n1 cp \n',
#  'Ship’s passage \n1 sp per mile \n',
#  'Spellcasting Services \n',
#  'Feats \n',
#  'Grappler \n',
#  'Prerequisite: Strength 13 or higher \n',
#  'Using Ability \nScores \n',
#  'Ability Scores and Modifiers \n',
#  'Score \nModifier \n',
#  'Typical Difficulty Classes \n',
#  'Task Difficulty \nDC \n',
#  'Very easy \n5 \n',
#  'Easy \n10 \n',
#  'Medium \n15 \n',
#  'Hard \n20 \n',
#  'Very hard \n25 \n',
#  'Nearly impossible \n30 \n',
#  'Contests \n',
#  'Skills \n',
#  'Strength \n• Athletics\n',
#  'Passive Checks \n',
#  'Working Together \n',
#  'Strength \n',
#  'Dexterity \n',
#  'Hiding \n',
#  'Constitution \n',
#  'Intelligence \n',
#  'Wisdom \n',
#  'Charisma \n',
#  'Speed \n',
#  'Travel Pace \n',
#  'Fast \n400 \nfeet \n',
#  'Normal \n300 \nfeet \n',
#  'Slow \n200 \nfeet \n',
#  'Special Types of Movement \n',
#  'Falling \n',
#  'Suffocating \n',
#  'Vision and Light \n',
#  'Food and Water \n',
#  'Interacting with Objects \n',
#  'Short Rest \n',
#  'Long Rest \n',
#  'Lifestyle Expenses \n',
#  'Downtime Activities \n',
#  'Combat Step by Step \n',
#  'Surprise \n',
#  'Initiative \n',
#  'Your Turn \n',
#  'Reactions \n',
#  'Breaking Up Your Move \n',
#  'Difficult Terrain \n',
#  'Being Prone \n',
#  'Interacting with Objects Around You \n',
#  'Moving Around Other Creatures \n',
#  'Flying Movement \n',
#  'Creature Size \n',
#  'Size Categories \n',
#  'Size \nSpace \n',
#  'Tiny \n2½ by 2½ ft. \n',
#  'Small \n5 by 5 ft. \n',
#  'Medium \n5 by 5 ft. \n',
#  'Large \n10 by 10 ft. \n',
#  'Huge \n15 by 15 ft. \n',
#  'Gargantuan \n20 by 20 ft. or larger \n',
#  'Attack \n',
#  'Cast a Spell \n',
#  'Dash \n',
#  'Disengage \n',
#  'Dodge \n',
#  'Help \n',
#  'Hide \n',
#  'Ready \n',
#  'Search \n',
#  'Use an Object \n',
#  'Attack Rolls \n',
#  'Unseen Attackers and Targets \n',
#  'Ranged Attacks \n',
#  'Melee Attacks \n',
#  'Contests in Combat \n',
#  'Hit Points \n',
#  'Damage Rolls \n',
#  'Damage Resistance and \nVulnerability \n',
#  'Healing \n',
#  'Dropping to 0 Hit Points \n',
#  'Knocking a Creature Out \n',
#  'Temporary Hit Points \n',
#  'Mounting and Dismounting \n',
#  'Controlling a Mount \n',
#  'Spellcasting \n',
#  'Spell Level \n',
#  'Known and Prepared Spells \n',
#  'Spell Slots \n',
#  'Casting in Armor \n',
#  'Cantrips \n',
#  'Rituals \n',
#  'Casting Time \n',
#  'Range \n',
#  'Components \n',
#  'Duration \n',
#  'Targets \n',
#  'Areas of Effect \n',
#  'Saving Throws \n',
#  'Attack Rolls \n',
#  'The Schools of Magic \n',
#  'Combining Magical Effects \n',
#  'Spell Lists \nBard Spells \n',
#  'Cleric Spells \n',
#  'Locate Creature \nStone Shape \n',
#  'Druid Spells \n',
#  'Paladin Spells \n',
#  'Ranger Spells \n',
#  'Stoneskin \n',
#  'Sorcerer Spells \n',
#  'Warlock Spells \n',
#  'True Seeing \n',
#  'Wizard Spells \n',
#  'Spell Descriptions \n',
#  'Acid Arrow \n2nd-\xad‐‑level evocation \n',
#  'Acid Splash \nConjuration cantrip \n',
#  'Aid \n2nd-\xad‐‑level abjuration \n',
#  'Duration: 8 hours \n',
#  'Alter Self \n2nd-\xad‐‑level transmutation \n',
#  'Animate Dead \n3rd-\xad‐‑level necromancy \n',
#  'Duration: Instantaneous \n',
#  'Animated Object Statistics \n',
#  'Size \nHP \nAC \nAttack \nStr \nDex \n',
#  'Duration: 10 days \n',
#  'Arcane Eye \n4th-\xad‐‑level divination \n',
#  'Arcane Hand \n5th-\xad‐‑level evocation \n',
#  'Arcane Lock \n2nd-\xad‐‑level abjuration \n',
#  'Casting Time: 1 action \n',
#  'Arcane Sword \n7th-\xad‐‑level evocation \n',
#  'Duration: Special \n',
#  'Awaken \n5th-\xad‐‑level transmutation \n',
#  'Casting Time: 8 hours \n',
#  'Duration: Instantaneous \n',
#  'Bane \n1st-\xad‐‑level enchantment \n',
#  'Banishment \n4th-\xad‐‑level abjuration \n',
#  'Barkskin \n2nd-\xad‐‑level transmutation \n',
#  'Bestow Curse \n3rd-\xad‐‑level necromancy \n',
#  'Blade Barrier \n6th-\xad‐‑level evocation \n',
#  'Bless \n1st-\xad‐‑level enchantment \n',
#  'Blight \n4th-\xad‐‑level necromancy \n',
#  'Blink \n3rd-\xad‐‑level transmutation \n',
#  'Blur \n2nd-\xad‐‑level illusion \n',
#  'Branding Smite \n2nd-\xad‐‑level evocation \n',
#  'Burning Hands \n1st-\xad‐‑level evocation \n',
#  'Charm Person \n1st-\xad‐‑level enchantment \n',
#  'Chill Touch \nNecromancy cantrip \n',
#  'Components: V, S \nDuration: 1 round \n',
#  'Duration: Instantaneous \n',
#  'Clairvoyance \n3rd-\xad‐‑level divination \n',
#  'Clone \n8th-\xad‐‑level necromancy \n',
#  'Cloudkill \n5th-\xad‐‑level conjuration \n',
#  'Color Spray \n1st-\xad‐‑level illusion \n',
#  'Duration: 1 round \n',
#  'Command \n1st-\xad‐‑level enchantment \n',
#  'Compulsion \n4th-\xad‐‑level enchantment \n',
#  'Cone of Cold \n5th-\xad‐‑level evocation \n',
#  'Confusion \n4th-\xad‐‑level enchantment \n',
#  'Conjure Fey \n6th-\xad‐‑level conjuration \n',
#  'Contagion \n5th-\xad‐‑level necromancy \n',
#  'Contingency \n6th-\xad‐‑level evocation \n',
#  'Precipitation \n',
#  'Stage \nCondition \n',
#  'Temperature \n',
#  'Stage \nCondition \n',
#  'Wind \n',
#  'Stage \nCondition \n',
#  'Counterspell \n3rd-\xad‐‑level abjuration \n',
#  'Create Undead \n6th-\xad‐‑level necromancy \n',
#  'Creation \n5th-\xad‐‑level illusion \n',
#  'Duration: Special \n',
#  'Material \nDuration \n',
#  'Vegetable matter \n1 day \n',
#  'Stone or crystal \n12 hours \n',
#  'Precious metals \n1 hour \n',
#  'Gems \n10 minutes \n',
#  'Adamantine or mithral \n1 minute \n',
#  'Cure Wounds \n1st-\xad‐‑level evocation \n',
#  'Dancing Lights \nEvocation cantrip \n',
#  'Darkness \n2nd-\xad‐‑level evocation \n',
#  'Darkvision \n2nd-\xad‐‑level transmutation \n',
#  'Duration: 8 hours \n',
#  'Daylight \n3rd-\xad‐‑level evocation \n',
#  'Death Ward \n4th-\xad‐‑level abjuration \n',
#  'Casting Time: 1 action \n',
#  'Demiplane \n8th-\xad‐‑level conjuration \n',
#  'Components: V \nDuration: Instantaneous \n',
#  'Disguise Self \n1st-\xad‐‑level illusion \n',
#  'Casting Time: 1 action \nRange: 60 feet \n',
#  'Dispel Magic \n3rd-\xad‐‑level abjuration \n',
#  'Duration: Instantaneous \n',
#  'Divine Favor \n1st-\xad‐‑level evocation \n',
#  'Divine Word \n7th-\xad‐‑level evocation \n',
#  'Dream \n5th-\xad‐‑level illusion \n',
#  'Druidcraft \nTransmutation cantrip \n',
#  'Earthquake \n8th-\xad‐‑level evocation \n',
#  'Eldritch Blast \nEvocation cantrip \n',
#  'Entangle \n1st-\xad‐‑level conjuration \n',
#  'Enthrall \n2nd-\xad‐‑level enchantment \n',
#  'Eyebite \n6th-\xad‐‑level necromancy \n',
#  'Fabricate \n4th-\xad‐‑level transmutation \n',
#  'Faerie Fire \n1st-\xad‐‑level evocation \n',
#  'False Life \n1st-\xad‐‑level necromancy \n',
#  'Fear \n3rd-\xad‐‑level illusion \n',
#  'Duration: 1 minute \n',
#  'Feeblemind \n8th-\xad‐‑level enchantment \n',
#  'Duration: Instantaneous \n',
#  'Find Steed \n2nd-\xad‐‑level conjuration \n',
#  'Find the Path \n6th-\xad‐‑level divination \n',
#  'Duration: Concentration, up to 1 day \n',
#  'Find Traps \n2nd-\xad‐‑level divination \n',
#  'Fireball \n3rd-\xad‐‑level evocation \n',
#  'Fire Bolt \nEvocation cantrip \n',
#  'Fire Shield \n4th-\xad‐‑level evocation \n',
#  'Duration: 10 minutes \n',
#  'Fire Storm \n7th-\xad‐‑level evocation \n',
#  'Flame Blade \n2nd-\xad‐‑level evocation \n',
#  'Flame Strike \n5th-\xad‐‑level evocation \n',
#  'Fly \n3rd-\xad‐‑level transmutation \n',
#  'Fog Cloud \n1st-\xad‐‑level conjuration \n',
#  'Duration: 1 day \n',
#  'Forcecage \n7th-\xad‐‑level evocation \n',
#  'Foresight \n9th-\xad‐‑level divination \n',
#  'Duration: 1 hour \n',
#  'Gate \n9th-\xad‐‑level conjuration \n',
#  'Geas \n5th-\xad‐‑level enchantment \n',
#  'Duration: 10 days \n',
#  'Glibness \n8th-\xad‐‑level transmutation \n',
#  'Duration: Until dispelled or triggered \n',
#  'Goodberry \n1st-\xad‐‑level transmutation \n',
#  'Grease \n1st-\xad‐‑level conjuration \n',
#  'Duration: Instantaneous \n',
#  'Guidance \nDivination cantrip \n',
#  'Guiding Bolt \n1st-\xad‐‑level evocation \n',
#  'Gust of Wind \n2nd-\xad‐‑level evocation \n',
#  'Hallow \n5th-\xad‐‑level evocation \n',
#  'Duration: 24 hours \n',
#  'Harm \n6th-\xad‐‑level necromancy \n',
#  'Haste \n3rd-\xad‐‑level transmutation \n',
#  'Heal \n6th-\xad‐‑level evocation \n',
#  'Healing Word \n1st-\xad‐‑level evocation \n',
#  'Heat Metal \n2nd-\xad‐‑level transmutation \n',
#  'Hellish Rebuke \n1st-\xad‐‑level evocation \n',
#  'Heroism \n1st-\xad‐‑level enchantment \n',
#  'Hold Monster \n5th-\xad‐‑level enchantment \n',
#  'Hold Person \n2nd-\xad‐‑level enchantment \n',
#  'Holy Aura \n8th-\xad‐‑level abjuration \n',
#  'Hunter’s Mark \n1st-\xad‐‑level divination \n',
#  'Ice Storm \n4th-\xad‐‑level evocation \n',
#  'Duration: Instantaneous \n',
#  'Duration: Instantaneous \n',
#  'Imprisonment \n9th-\xad‐‑level abjuration \n',
#  'Invisibility \n2nd-\xad‐‑level illusion \n',
#  'Duration: Concentration, up to 1 hour \n',
#  'Jump \n1st-\xad‐‑level transmutation \n',
#  'Knock \n2nd-\xad‐‑level transmutation \n',
#  'Legend Lore \n5th-\xad‐‑level divination \n',
#  'Duration: Instantaneous \n',
#  'Levitate \n2nd-\xad‐‑level transmutation \n',
#  'Casting Time: 1 action \nRange: 60 feet \n',
#  'Light \nEvocation cantrip \n',
#  'Lightning Bolt \n3rd-\xad‐‑level evocation \n',
#  'Duration: Instantaneous \n',
#  'Duration: Concentration, up to 1 hour \n',
#  'Locate Object \n2nd-\xad‐‑level divination \n',
#  'Mage Armor \n1st-\xad‐‑level abjuration \n',
#  'Mage Hand \nConjuration cantrip \n',
#  'Magic Circle \n3rd-\xad‐‑level abjuration \n',
#  'Duration: 1 hour \n',
#  'Magic Jar \n6th-\xad‐‑level necromancy \n',
#  'Duration: Until dispelled \n',
#  'Magic Missile \n1st-\xad‐‑level evocation \n',
#  'Duration: Until dispelled \n',
#  'Major Image \n3rd-\xad‐‑level illusion \n',
#  'Casting Time: 1 action \n',
#  'Mass Heal \n9th-\xad‐‑level evocation \n',
#  'Maze \n8th-\xad‐‑level conjuration \n',
#  'Mending \nTransmutation cantrip \n',
#  'Message \nTransmutation cantrip \n',
#  'Meteor Swarm \n9th-\xad‐‑level evocation \n',
#  'Mind Blank \n8th-\xad‐‑level abjuration \n',
#  'Minor Illusion \nIllusion cantrip \n',
#  'Mirage Arcane \n7th-\xad‐‑level illusion \n',
#  'Mirror Image \n2nd-\xad‐‑level illusion \n',
#  'Mislead \n5th-\xad‐‑level illusion \n',
#  'Misty Step \n2nd-\xad‐‑level conjuration \n',
#  'Moonbeam \n2nd-\xad‐‑level evocation \n',
#  'Move Earth \n6th-\xad‐‑level transmutation \n',
#  'Duration: Concentration, up to 2 hours \n',
#  'Nondetection \n3rd-\xad‐‑level abjuration \n',
#  'Passwall \n5th-\xad‐‑level transmutation \n',
#  'Casting Time: 1 action \n',
#  'Planar Ally \n6th-\xad‐‑level conjuration \n',
#  'Duration: 24 hours \n',
#  'Plane Shift \n7th-\xad‐‑level conjuration \n',
#  'Duration: Instantaneous \n',
#  'Poison Spray \nConjuration cantrip \n',
#  'Polymorph \n4th-\xad‐‑level transmutation \n',
#  'Duration: 24 hours \n',
#  'Produce Flame \nConjuration cantrip \n',
#  'Duration: Until dispelled \n',
#  'Project Image \n7th-\xad‐‑level illusion \n',
#  'Duration: Concentration, up to 1 day \n',
#  'Casting Time: 1 action \n',
#  'Raise Dead \n5th-\xad‐‑level necromancy \n',
#  'Duration: Instantaneous \n',
#  'Ray of Frost \nEvocation cantrip \n',
#  'Regenerate \n7th-\xad‐‑level transmutation \n',
#  'Duration: Instantaneous \n',
#  'Remove Curse \n3rd-\xad‐‑level abjuration \n',
#  'Resistance \nAbjuration cantrip \n',
#  'Resurrection \n7th-\xad‐‑level necromancy \n',
#  'Revivify \n3rd-\xad‐‑level necromancy \n',
#  'Duration: Instantaneous \n',
#  'Rope Trick \n2nd-\xad‐‑level transmutation \n',
#  'Sacred Flame \nEvocation cantrip \n',
#  'Sanctuary \n1st-\xad‐‑level abjuration \n',
#  'Scorching Ray \n2nd-\xad‐‑level evocation \n',
#  'Scrying \n5th-\xad‐‑level divination \n',
#  'Knowledge \nSave Modifier \n',
#  'Firsthand (you have met the target) \n+0\n',
#  'Familiar (you know the target well) \n−5\n',
#  'Connection \nSave Modifier \n',
#  'Likeness or picture \n−2\n',
#  'Possession or garment \n−4\n',
#  'Secret Chest \n4th-\xad‐‑level conjuration \n',
#  'Seeming \n5th-\xad‐‑level illusion \n',
#  'Sending \n3rd-\xad‐‑level evocation \n',
#  'Duration: 1 round \n',
#  'Sequester \n7th-\xad‐‑level transmutation \n',
#  'Shatter \n2nd-\xad‐‑level evocation \n',
#  'Shield \n1st-\xad‐‑level abjuration \n',
#  'Shillelagh \nTransmutation cantrip \n',
#  'Shocking Grasp \nEvocation cantrip \n',
#  'Silent Image \n1st-\xad‐‑level illusion \n',
#  'Simulacrum \n7th-\xad‐‑level illusion \n',
#  'Sleep \n1st-\xad‐‑level enchantment \n',
#  'Duration: 1 minute \n',
#  'Sleet Storm \n3rd-\xad‐‑level conjuration \n',
#  'Slow \n3rd-\xad‐‑level transmutation \n',
#  'Spare the Dying \nNecromancy cantrip \n',
#  'Casting Time: 1 action \nRange: 10 feet \n',
#  'Stoneskin \n4th-\xad‐‑level abjuration \n',
#  'Suggestion \n2nd-\xad‐‑level enchantment \n',
#  'Duration: Concentration, up to 8 hours \n',
#  'Sunbeam \n6th-\xad‐‑level evocation \n',
#  'Sunburst \n8th-\xad‐‑level evocation \n',
#  'Symbol \n7th-\xad‐‑level abjuration \n',
#  'Duration: Until dispelled or triggered \n',
#  'Duration: 1 hour \n',
#  'Teleport \n7th-\xad‐‑level conjuration \n',
#  'Familiarity \nMishap \n',
#  'Permanent \ncircle \n',
#  'Associated \nobject \n',
#  'False \ndestination \n',
#  'Duration: 1 round \n',
#  'Thaumaturgy \nTransmutation cantrip \n',
#  'Thunderwave \n1st-\xad‐‑level evocation \n',
#  'Time Stop \n9th-\xad‐‑level transmutation \n',
#  'Tongues \n3rd-\xad‐‑level divination \n',
#  'Tree Stride \n5th-\xad‐‑level conjuration \n',
#  'True Seeing \n6th-\xad‐‑level divination \n',
#  'True Strike \nDivination cantrip \n',
#  'Duration: 1 hour \n',
#  'Vicious Mockery \nEnchantment cantrip \n',
#  'Wall of Fire \n4th-\xad‐‑level evocation \n',
#  'Wall of Force \n5th-\xad‐‑level evocation \n',
#  'Wall of Ice \n6th-\xad‐‑level evocation \n',
#  'Wall of Stone \n5th-\xad‐‑level evocation \n',
#  'Casting Time: 1 action \n',
#  'Warding Bond \n2nd-\xad‐‑level abjuration \n',
#  'Duration: 1 hour \n',
#  'Casting Time: 1 action \n',
#  'Web \n2nd-\xad‐‑level conjuration \n',
#  'Weird \n9th-\xad‐‑level illusion \n',
#  'Wind Walk \n6th-\xad‐‑level transmutation \n',
#  'Wind Wall \n3rd-\xad‐‑level evocation \n',
#  'Wish \n9th-\xad‐‑level conjuration \n',
#  'Traps in Play \n',
#  'Trap Save DCs and Attack Bonuses \n',
#  'Trap Danger \nSave DC \nAttack Bonus \n',
#  'Setback \n10–11 \n+3 to +5\n',
#  'Dangerous \n12–15 \n+6 to +8\n',
#  'Deadly \n16–20 \n+9 to +12\n',
#  'Damage Severity by Level \n',
#  'Sample Traps \n',
#  'Collapsing Roof \nMechanical trap \n',
#  'Falling Net \nMechanical trap \n',
#  'Fire-Breathing Statue \nMagic trap \n',
#  'Pits \nMechanical trap \n',
#  'Poison Darts \nMechanical trap \n',
#  'Poison Needle \nMechanical trap \n',
#  'Rolling Sphere \nMechanical trap \n',
#  'Sphere of Annihilation \nMagic trap \n',
#  'Sample Diseases \n',
#  'Going Mad \n',
#  'Madness Effects \n',
#  'Short-\xad‐Term Madness \n',
#  'Long-\xad‐Term Madness \n',
#  'Indefinite Madness \n',
#  'Curing Madness \n',
#  'Object Armor Class \n',
#  'Substance \nAC \n',
#  'Cloth, paper, rope \n11 \n',
#  'Crystal, glass, ice \n13 \n',
#  'Wood, bone \n15 \n',
#  'Stone \n17 \n',
#  'Iron, steel \n19 \n',
#  'Mithral \n21 \n',
#  'Adamantine \n23 \n',
#  'Object Hit Points \n',
#  'Size \nFragile \nResilient \n',
#  'Tiny (bottle, lock) \n2 (1d4) \n5 (2d4) \n',
#  'Small (chest, lute) \n3 (1d6) \n10 (3d6) \n',
#  'Poisons \n',
#  'Item \nType \nPrice per Dose \n',
#  'Assassin’s blood \nIngested \n150 gp \n',
#  'Burnt othur fumes \nInhaled \n500 gp \n',
#  'Crawler mucus \nContact \n200 gp \n',
#  'Drow poison \nInjury \n200 gp \n',
#  'Essence of ether \nInhaled \n300 gp \n',
#  'Malice \nInhaled \n250 gp \n',
#  'Midnight tears \nIngested \n1,500 gp \n',
#  'Oil of taggit \nContact \n400 gp \n',
#  'Pale tincture \nIngested \n250 gp \n',
#  'Purple worm poison \nInjury \n2,000 gp \n',
#  'Serpent venom \nInjury \n200 gp \n',
#  'Torpor \nIngested \n600 gp \n',
#  'Truth serum \nIngested \n150 gp \n',
#  'Wyvern poison \nInjury \n1,200 gp \n',
#  'Sample Poisons \n',
#  'Magic Items \n',
#  'Multiple Items of the Same Kind \n',
#  'Paired Items \n',
#  'Command Word \n',
#  'Consumables \n',
#  'Spells \n',
#  'Charges \n',
#  'Magic Items A-Z \n',
#  'Apparatus of the Crab Levers \n',
#  'Lever \nUp \nDown \n',
#  'Bag of Beans \nWondrous item, rare \n',
#  'Bag of Tricks \nWondrous item, uncommon \n',
#  'Gray Bag of Tricks \n',
#  'Rust Bag of Tricks \n',
#  'Tan Bag of Tricks \n',
#  'Bead of Force \nWondrous item, rare \n',
#  'Type \nStrength \nRarity \n',
#  'Hill giant \n21 \nRare \n',
#  'Stone/frost giant \n23 \nVery rare \n',
#  'Fire giant \n25 \nVery rare \n',
#  'Cloud giant \n27 \nLegendary \n',
#  'Storm giant \n29 \nLegendary \n',
#  'Chime of Opening \nWondrous item, rare \n',
#  'Cube of Force Faces \n',
#  'Face \nCharges \nEffect \n',
#  'Spell or Item \nCharges Lost \n',
#  'Disintegrate \n1d12 \n',
#  'Horn of blasting \n1d10 \n',
#  'Passwall \n1d6 \n',
#  'Prismatic spray \n1d20 \n',
#  'Wall of fire \n1d4 \n',
#  'Cubic Gate \nWondrous item, legendary \n',
#  'Dagger of Venom \nWeapon (dagger), rare \n',
#  'Playing Card \nIllusion \n',
#  'Ace of hearts \nRed dragon \n',
#  'King of hearts \nKnight and four guards \n',
#  'Queen of hearts \nSuccubus or incubus \n',
#  'Jack of hearts \nDruid \n',
#  'Ten of hearts \nCloud giant \n',
#  'Nine of hearts \nEttin \n',
#  'Eight of hearts \nBugbear \n',
#  'Two of hearts \nGoblin \n',
#  'Ace of diamonds \nBeholder \n',
#  'Queen of diamonds \nNight hag \n',
#  'Jack of diamonds \nAssassin \n',
#  'Ten of diamonds \nFire giant \n',
#  'Nine of diamonds \nOgre mage \n',
#  'Eight of diamonds \nGnoll \n',
#  'Two of diamonds \nKobold \n',
#  'Ace of spades \nLich \n',
#  'Queen of spades \nMedusa \n',
#  'Jack of spades \nVeteran \n',
#  'Ten of spades \nFrost giant \n',
#  'Nine of spades \nTroll \n',
#  'Eight of spades \nHobgoblin \n',
#  'Two of spades \nGoblin \n',
#  'Ace of clubs \nIron golem \n',
#  'Queen of clubs \nErinyes \n',
#  'Jack of clubs \nBerserker \n',
#  'Ten of clubs \nHill giant \n',
#  'Nine of clubs \nOgre \n',
#  'Eight of clubs \nOrc \n',
#  'Two of clubs \nKobold \n',
#  'Jokers (2) \nYou (the deck’s owner) \n',
#  'Playing Card \nCard \n',
#  'Ace of diamonds \nVizier* \n',
#  'King of diamonds \nSun \n',
#  'Queen of diamonds \nMoon \n',
#  'Jack of diamonds \nStar \n',
#  'Two of diamonds \nComet* \n',
#  'Ace of hearts \nThe Fates* \n',
#  'King of hearts \nThrone \n',
#  'Queen of hearts \nKey \n',
#  'Jack of hearts \nKnight \n',
#  'Two of hearts \nGem* \n',
#  'Ace of clubs \nTalons* \n',
#  'King of clubs \nThe Void \n',
#  'Queen of clubs \nFlames \n',
#  'Jack of clubs \nSkull \n',
#  'Two of clubs \nIdiot* \n',
#  'Ace of spades \nDonjon* \n',
#  'King of spades \nRuin \n',
#  'Queen of spades \nEuryale \n',
#  'Jack of spades \nRogue \n',
#  'Two of spades \nBalance* \n',
#  'Joker (with TM) \nFool* \n',
#  'Joker (without TM) \nJester \n',
#  'Avatar of Death \n',
#  'Medium undead, neutral evil \n',
#  'Armor Class 20 \n',
#  'Speed 60 ft., fly 60 ft. (hover) \n',
#  'Damage Immunities necrotic, poison \n',
#  'Challenge — (0 XP) \n',
#  'Actions \n',
#  'Dragon \nResistance \nDragon \nResistance \n',
#  'Black \nAcid \nGold \nFire \n',
#  'Blue \nLightning \nGreen \nPoison \n',
#  'Brass \nFire \nRed \nFire \n',
#  'Bronze \nLightning \nSilver \nCold \n',
#  'Copper \nAcid \nWhite \nCold \n',
#  'Elemental Gem \nWondrous item, uncommon \n',
#  'Gem \nSummoned Elemental \n',
#  'Blue sapphire \nAir elemental \n',
#  'Yellow diamond \nEarth elemental \n',
#  'Red corundum \nFire elemental \n',
#  'Emerald \nWater elemental \n',
#  'Elven Chain \nArmor (chain shirt), rare \n',
#  'Feather Token \nWondrous item, rare \n',
#  'Giant Fly \n',
#  'Large beast, unaligned \n',
#  'Armor Class 11 \n',
#  'Hit Points 19 (3d10 + 3) \n',
#  'Speed 30 ft., fly 60 ft. \n',
#  'Languages — \n',
#  'Folding Boat \nWondrous item, rare \n',
#  'Handy Haversack \nWondrous item, rare \n',
#  'Horn of Blasting \nWondrous item, rare \n',
#  'Immovable Rod \nRod, uncommon \n',
#  'Instant Fortress \nWondrous item, rare \n',
#  'Iron Flask \nWondrous item, legendary \n',
#  'Mace of Smiting \nWeapon (mace), rare \n',
#  'Oil of Etherealness \nPotion, rare \n',
#  'Oil of Sharpness \nPotion, very rare \n',
#  'Oil of Slipperiness \nPotion, uncommon \n',
#  'Philter of Love \nPotion, uncommon \n',
#  'Portable Hole \nWondrous item, rare \n',
#  'Potion of Clairvoyance \nPotion, rare \n',
#  'Potion of Climbing \nPotion, common \n',
#  'Potion of Diminution \nPotion, rare \n',
#  'Potion of Flying \nPotion, very rare \n',
#  'Potion of Gaseous Form \nPotion, rare \n',
#  'Type of Giant \nStrength \nRarity \n',
#  'Hill giant \n21 \nUncommon \n',
#  'Frost/stone giant \n23 \nRare \n',
#  'Fire giant \n25 \nRare \n',
#  'Cloud giant \n27 \nVery rare \n',
#  'Storm giant \n29 \nLegendary \n',
#  'Potion of Growth \nPotion, uncommon \n',
#  'Potions of Healing \n',
#  'Potion of … \nRarity \nHP Regained \n',
#  'Healing \nCommon \n2d4 + 2 \n',
#  'Greater healing \nUncommon \n4d4 + 4 \n',
#  'Superior healing \nRare \n8d4 + 8 \n',
#  'Supreme healing \nVery rare \n10d4 + 20 \n',
#  'Potion of Heroism \nPotion, rare \n',
#  'Potion of Mind Reading \nPotion, rare \n',
#  'Potion of Poison \nPotion, uncommon \n',
#  'Potion of Resistance \nPotion, uncommon \n',
#  'Potion of Speed \nPotion, very rare \n',
#  'Ring of Animal Influence \nRing, rare \n',
#  'Spheres \nLightning Damage \n',
#  'Ring of Swimming \nRing, uncommon \n',
#  'Ring of Three Wishes \nRing, legendary \n',
#  'Ring of Water Walking \nRing, uncommon \n',
#  'Rod of Security \nRod, very rare \n',
#  'Spell Scroll \nScroll, varies \n',
#  'Spell Scroll \n',
#  'Cantrip \nCommon \n13 \n+5\n',
#  'Distance from Origin \nDamage \n',
#  'Distance from Origin \nDamage \n',
#  'Vicious Weapon \nWeapon (any), rare \n',
#  'Wand of Magic Missiles \nWand, uncommon \n',
#  'Wand of Secrets \nWand, uncommon \n',
#  'Wind Fan \nWondrous item, uncommon \n',
#  'Creating Sentient Magic Items \n',
#  'Conflict \n',
#  'Artifacts \n',
#  'Monsters \n',
#  'Size \n',
#  'Size Categories \n',
#  'Size \nSpace \nExamples \n',
#  'Tiny \n2½ by 2½ ft. \nImp, sprite \n',
#  'Small \n5 by 5 ft. \nGiant rat, goblin \n',
#  'Medium \n5 by 5 ft. \nOrc, werewolf \n',
#  'Large \n10 by 10 ft. \nHippogriff, ogre \n',
#  'Huge \n15 by 15 ft. \nFire giant, treant \n',
#  'Modifying Creatures \n',
#  'Type \n',
#  'Alignment \n',
#  'Armor Class \n',
#  'Hit Points \n',
#  'Hit Dice by Size \n',
#  'Tiny \nd4 \n2½ \n',
#  'Small \nd6 \n3½ \n',
#  'Medium \nd8 \n4½ \n',
#  'Large \nd10 \n5½ \n',
#  'Huge \nd12 \n6½ \n',
#  'Gargantuan \nd20 \n10½ \n',
#  'Speed \n',
#  'Ability Scores \n',
#  'Saving Throws \n',
#  'Proficiency Bonus by Challenge Rating \n',
#  'Challenge \n',
#  'Skills \n',
#  'Senses \n',
#  'Armor, Weapon, and Tool Proficiencies \n',
#  'Languages \n',
#  'Challenge \n',
#  'Experience Points by Challenge Rating \n',
#  'Challenge \nXP \nChallenge \nXP \n',
#  'Special Traits \n',
#  'Actions \n',
#  'Reactions \n',
#  'Limited Usage \n',
#  'Grapple Rules for Monsters \n',
#  'Equipment \n',
#  'Legendary Actions \n',
#  'A Legendary Creature’s Lair \n',
#  'Monsters (A) \n',
#  'Aboleth \n',
#  'Large aberration, lawful evil \n',
#  'Armor Class 17 (natural armor) \n',
#  'Hit Points 135 (18d10 + 36) \n',
#  'Speed 10 ft., swim 40 ft. \n',
#  'Saving Throws Con +6, Int +8, Wis +6 \n',
#  'Skills History +12, Perception +10 \n',
#  'Challenge 10 (5,900 XP) \n',
#  'Actions \n',
#  'Legendary Actions \n',
#  'Angels \n',
#  'Deva \n',
#  'Medium celestial, lawful good \n',
#  'Armor Class 17 (natural armor) \n',
#  'Hit Points 136 (16d8 + 64) \n',
#  'Speed 30 ft., fly 90 ft. \n',
#  'Saving Throws Wis +9, Cha +9 \n',
#  'Skills Insight +9, Perception +9 \n',
#  'Languages all, telepathy 120 ft. \n',
#  'Challenge 10 (5,900 XP) \n',
#  'At will: detect evil and good \n',
#  'Actions \n',
#  'Planetar \n',
#  'Large celestial, lawful good  \n',
#  'Armor Class 19 (natural armor) \n',
#  'Hit Points 200 (16d10 + 112) \n',
#  'Speed 40 ft., fly 120 ft. \n',
#  'Skills Perception +11 \n',
#  'Languages all, telepathy 120 ft. \n',
#  'Challenge 16 (15,000 XP) \n',
#  'Actions \n',
#  'Solar \n',
#  'Large celestial, lawful good \n',
#  'Armor Class 21 (natural armor) \n',
#  'Hit Points 243 (18d10 + 144) \n',
#  'Speed 50 ft., fly 150 ft. \n',
#  'Skills Perception +14 \n',
#  'Damage Immunities necrotic, poison \n',
#  'Languages all, telepathy 120 ft. \n',
#  'Challenge 21 (33,000 XP) \n',
#  'Actions \n',
#  'Legendary Actions \n',
#  'Animated Objects \n',
#  'Animated Armor \n',
#  'Medium construct, unaligned \n',
#  'Armor Class 18 (natural armor) \n',
#  'Hit Points 33 (6d8 + 6) \n',
#  'Speed 25 ft. \n',
#  'Damage Immunities poison, psychic \n',
#  'Languages — \n',
#  'Challenge 1 (200 XP) \n',
#  'Actions \n',
#  'Flying Sword \n',
#  'Small construct, unaligned \n',
#  'Armor Class 17 (natural armor) \n',
#  'Hit Points 17 (5d6) \n',
#  'Speed 0 ft., fly 50 ft. (hover) \n',
#  'Saving Throws Dex +4 \n',
#  'Damage Immunities poison, psychic \n',
#  'Languages — \n',
#  'Challenge 1/4 (50 XP) \n',
#  'Actions \n',
#  'Rug of Smothering \n',
#  'Large construct, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 33 (6d10) \n',
#  'Speed 10 ft. \n',
#  'Damage Immunities poison, psychic \n',
#  'Languages — \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Ankheg \n',
#  'Large monstrosity, unaligned \n',
#  'Hit Points 39 (6d10 + 6) \n',
#  'Speed 30 ft., burrow 10 ft. \n',
#  'Languages — \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Azer \n',
#  'Medium elemental, lawful neutral \n',
#  'Armor Class 17 (natural armor, shield) \n',
#  'Hit Points 39 (6d8 + 12) \n',
#  'Speed 30 ft. \n',
#  'Saving Throws Con +4 \n',
#  'Damage Immunities fire, poison \n',
#  'Condition Immunities poisoned \n',
#  'Senses passive Perception 11 \n',
#  'Languages Ignan \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Monsters (B) \n',
#  'Basilisk \n',
#  'Medium monstrosity, unaligned \n',
#  'Armor Class 15 (natural armor) \n',
#  'Hit Points 52 (8d8 + 16) \n',
#  'Speed 20 ft. \n',
#  'Languages — \n',
#  'Challenge 3 (700 XP) \n',
#  'Actions \n',
#  'Behir \n',
#  'Huge monstrosity, neutral evil \n',
#  'Armor Class 17 (natural armor) \n',
#  'Hit Points 168 (16d12 + 64) \n',
#  'Speed 50 ft., climb 40 ft. \n',
#  'Skills Perception +6, Stealth +7 \n',
#  'Damage Immunities lightning \n',
#  'Languages Draconic \n',
#  'Challenge 11 (7,200 XP) \n',
#  'Actions \n',
#  'Bugbear \n',
#  'Armor Class 16 (hide armor, shield) \n',
#  'Hit Points 27 (5d8 + 5) \n',
#  'Speed 30 ft. \n',
#  'Skills Stealth +6, Survival +2 \n',
#  'Languages Common, Goblin \n',
#  'Challenge 1 (200 XP) \n',
#  'Actions \n',
#  'Bulette \n',
#  'Large monstrosity, unaligned \n',
#  'Armor Class 17 (natural armor) \n',
#  'Hit Points 94 (9d10 + 45) \n',
#  'Speed 40 ft., burrow 40 ft. \n',
#  'Skills Perception +6 \n',
#  'Languages — \n',
#  'Challenge 5 (1,800 XP) \n',
#  'Actions \n',
#  'Monsters (C) \n',
#  'Centaur \n',
#  'Large monstrosity, neutral good \n',
#  'Armor Class 12 \n',
#  'Hit Points 45 (6d10 + 12) \n',
#  'Speed 50 ft. \n',
#  'Senses passive Perception 13 \n',
#  'Languages Elvish, Sylvan \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Chimera \n',
#  'Large monstrosity, chaotic evil \n',
#  'Armor Class 14 (natural armor) \n',
#  'Hit Points 114 (12d10 + 48) \n',
#  'Speed 30 ft., fly 60 ft. \n',
#  'Skills Perception +8 \n',
#  'Challenge 6 (2,300 XP) \n',
#  'Actions \n',
#  'Chuul \n',
#  'Large aberration, chaotic evil \n',
#  'Armor Class 16 (natural armor) \n',
#  'Hit Points 93 (11d10 + 33) \n',
#  'Speed 30 ft., swim 30 ft. \n',
#  'Skills Perception +4 \n',
#  'Damage Immunities poison \n',
#  'Condition Immunities poisoned \n',
#  'Challenge 4 (1,100 XP) \n',
#  'Actions \n',
#  'Cloaker \n',
#  'Large aberration, chaotic neutral \n',
#  'Armor Class 14 (natural armor) \n',
#  'Hit Points 78 (12d10 + 12) \n',
#  'Speed 10 ft., fly 40 ft. \n',
#  'Skills Stealth +5 \n',
#  'Languages Deep Speech, Undercommon \n',
#  'Challenge 8 (3,900 XP) \n',
#  'Actions \n',
#  'Cockatrice \n',
#  'Small monstrosity, unaligned \n',
#  'Armor Class 11 \n',
#  'Hit Points 27 (6d6 + 6) \n',
#  'Speed 20 ft., fly 40 ft. \n',
#  'Languages — \n',
#  'Challenge 1/2 (100 XP) \n',
#  'Actions \n',
#  'Couatl \n',
#  'Medium celestial, lawful good \n',
#  'Armor Class 19 (natural armor) \n',
#  'Hit Points 97 (13d8 + 39) \n',
#  'Speed 30 ft., fly 90 ft. \n',
#  'Saving Throws Con +5, Wis +7, Cha +6 \n',
#  'Damage Resistances radiant \n',
#  'Languages all, telepathy 120 ft. \n',
#  'Challenge 4 (1,100 XP) \n',
#  'Actions \n',
#  'Monsters (D) \n',
#  'Darkmantle \n',
#  'Small monstrosity, unaligned \n',
#  'Armor Class 11 \n',
#  'Hit Points 22 (5d6 + 5) \n',
#  'Speed 10 ft., fly 30 ft. \n',
#  'Skills Stealth +3 \n',
#  'Languages — \n',
#  'Challenge 1/2 (100 XP) \n',
#  'Actions \n',
#  'Demons \n',
#  'Balor \n',
#  'Huge fiend (demon), chaotic evil \n',
#  'Armor Class 19 (natural armor) \n',
#  'Hit Points 262 (21d12 + 126) \n',
#  'Speed 40 ft., fly 80 ft. \n',
#  'Damage Immunities fire, poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Abyssal, telepathy 120 ft. \n',
#  'Challenge 19 (22,000 XP) \n',
#  'Actions \n',
#  'Dretch \n',
#  'Small fiend (demon), chaotic evil \n',
#  'Armor Class 11 (natural armor) \n',
#  'Hit Points 18 (4d6 + 4) \n',
#  'Speed 20 ft. \n',
#  'Damage Immunities poison \n',
#  'Condition Immunities poisoned \n',
#  'Challenge 1/4 (50 XP) \n',
#  'Actions \n',
#  'Glabrezu \n',
#  'Large fiend (demon), chaotic evil \n',
#  'Armor Class 17 (natural armor) \n',
#  'Hit Points 157 (15d10 + 75) \n',
#  'Speed 40 ft. \n',
#  'Damage Immunities poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Abyssal, telepathy 120 ft. \n',
#  'Challenge 9 (5,000 XP) \n',
#  'Actions \n',
#  'Hezrou \n',
#  'Large fiend (demon), chaotic evil \n',
#  'Armor Class 16 (natural armor) \n',
#  'Hit Points 136 (13d10 + 65) \n',
#  'Speed 30 ft. \n',
#  'Saving Throws Str +7, Con +8, Wis +4 \n',
#  'Damage Immunities poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Abyssal, telepathy 120 ft. \n',
#  'Challenge 8 (3,900 XP) \n',
#  'Actions \n',
#  'Marilith \n',
#  'Large fiend (demon), chaotic evil \n',
#  'Armor Class 18 (natural armor) \n',
#  'Hit Points 189 (18d10 + 90) \n',
#  'Speed 40 ft. \n',
#  'Damage Immunities poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Abyssal, telepathy 120 ft. \n',
#  'Challenge 16 (15,000 XP) \n',
#  'Actions \n',
#  'Reactions \n',
#  'Nalfeshnee \n',
#  'Large fiend (demon), chaotic evil \n',
#  'Armor Class 18 (natural armor) \n',
#  'Hit Points 184 (16d10 + 96) \n',
#  'Speed 20 ft., fly 30 ft. \n',
#  'Damage Immunities poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Abyssal, telepathy 120 ft. \n',
#  'Challenge 13 (10,000 XP) \n',
#  'Actions \n',
#  'Quasit \n',
#  'Armor Class 13 \n',
#  'Hit Points 7 (3d4) \n',
#  'Speed 40 ft. \n',
#  'Skills Stealth +5 \n',
#  'Damage Immunities poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Abyssal, Common \n',
#  'Challenge 1 (200 XP) \n',
#  'Actions \n',
#  'Vrock \n',
#  'Large fiend (demon), chaotic evil \n',
#  'Armor Class 15 (natural armor) \n',
#  'Hit Points 104 (11d10 + 44) \n',
#  'Speed 40 ft., fly 60 ft. \n',
#  'Saving Throws Dex +5, Wis +4, Cha +2 \n',
#  'Damage Immunities poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Abyssal, telepathy 120 ft. \n',
#  'Challenge 6 (2,300 XP) \n',
#  'Actions \n',
#  'Devils \n',
#  'Barbed Devil \n',
#  'Medium fiend (devil), lawful evil \n',
#  'Armor Class 15 (natural armor) \n',
#  'Hit Points 110 (13d8 + 52) \n',
#  'Speed 30 ft. \n',
#  'Damage Immunities fire, poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Infernal, telepathy 120 ft. \n',
#  'Challenge 5 (1,800 XP) \n',
#  'Actions \n',
#  'Bearded Devil \n',
#  'Medium fiend (devil), lawful evil \n',
#  'Armor Class 13 (natural armor) \n',
#  'Hit Points 52 (8d8 + 16) \n',
#  'Speed 30 ft. \n',
#  'Saving Throws Str +5, Con +4, Wis +2 \n',
#  'Damage Immunities fire, poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Infernal, telepathy 120 ft. \n',
#  'Challenge 3 (700 XP) \n',
#  'Actions \n',
#  'Bone Devil \n',
#  'Large fiend (devil), lawful evil \n',
#  'Armor Class 19 (natural armor) \n',
#  'Hit Points 142 (15d10 + 60) \n',
#  'Speed 40 ft., fly 40 ft. \n',
#  'Saving Throws Int +5, Wis +6, Cha +7 \n',
#  'Skills Deception +7, Insight +6 \n',
#  'Damage Immunities fire, poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Infernal, telepathy 120 ft. \n',
#  'Challenge 9 (5,000 XP) \n',
#  'Actions \n',
#  'Chain Devil \n',
#  'Medium fiend (devil), lawful evil \n',
#  'Armor Class 16 (natural armor) \n',
#  'Hit Points 85 (10d8 + 40) \n',
#  'Speed 30 ft. \n',
#  'Saving Throws Con +7, Wis +4, Cha +5 \n',
#  'Damage Immunities fire, poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Infernal, telepathy 120 ft. \n',
#  'Challenge 8 (3,900 XP) \n',
#  'Actions \n',
#  'Reactions \n',
#  'Erinyes \n',
#  'Medium fiend (devil), lawful evil \n',
#  'Armor Class 18 (plate) \n',
#  'Hit Points 153 (18d8 + 72) \n',
#  'Speed 30 ft., fly 60 ft. \n',
#  'Damage Immunities fire, poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Infernal, telepathy 120 ft. \n',
#  'Challenge 12 (8,400 XP) \n',
#  'Actions \n',
#  'Reactions \n',
#  'Horned Devil \n',
#  'Large fiend (devil), lawful evil \n',
#  'Armor Class 18 (natural armor) \n',
#  'Hit Points 178 (17d10 + 85) \n',
#  'Speed 20 ft., fly 60 ft. \n',
#  'Damage Immunities fire, poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Infernal, telepathy 120 ft. \n',
#  'Challenge 11 (7,200 XP) \n',
#  'Actions \n',
#  'Ice Devil \n',
#  'Large fiend (devil), lawful evil \n',
#  'Armor Class 18 (natural armor) \n',
#  'Hit Points 180 (19d10 + 76) \n',
#  'Speed 40 ft. \n',
#  'Damage Immunities cold, fire, poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Infernal, telepathy 120 ft. \n',
#  'Challenge 14 (11,500 XP) \n',
#  'Actions \n',
#  'Imp \n',
#  'Armor Class 13 \n',
#  'Hit Points 10 (3d4 + 3) \n',
#  'Speed 20 ft., fly 40 ft. \n',
#  'Damage Immunities fire, poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Infernal, Common \n',
#  'Challenge 1 (200 XP) \n',
#  'Actions \n',
#  'Lemure \n',
#  'Medium fiend (devil), lawful evil \n',
#  'Armor Class 7 \n',
#  'Hit Points 13 (3d8) \n',
#  'Speed 15 ft. \n',
#  'Damage Resistances cold \n',
#  'Damage Immunities fire, poison \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Pit Fiend \n',
#  'Large fiend (devil), lawful evil \n',
#  'Armor Class 19 (natural armor) \n',
#  'Hit Points 300 (24d10 + 168) \n',
#  'Speed 30 ft., fly 60 ft. \n',
#  'Saving Throws Dex +8, Con +13, Wis +10 \n',
#  'Damage Immunities fire, poison \n',
#  'Condition Immunities poisoned \n',
#  'Languages Infernal, telepathy 120 ft. \n',
#  'Challenge 20 (25,000 XP) \n',
#  'At will: detect magic, fireball \n',
#  'Actions \n',
#  'Dinosaurs \n',
#  'Plesiosaurus \n',
#  'Large beast, unaligned \n',
#  'Armor Class 13 (natural armor) \n',
#  'Hit Points 68 (8d10 + 24) \n',
#  'Speed 20 ft., swim 40 ft. \n',
#  'Skills Perception +3, Stealth +4 \n',
#  'Senses passive Perception 13 \n',
#  'Languages — \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Triceratops \n',
#  'Huge beast, unaligned \n',
#  'Armor Class 13 (natural armor) \n',
#  'Hit Points 95 (10d12 + 30) \n',
#  'Speed 50 ft. \n',
#  'Senses passive Perception 10 \n',
#  'Languages — \n',
#  'Challenge 5 (1,800 XP) \n',
#  'Actions \n',
#  'Tyrannosaurus Rex \n',
#  'Huge beast, unaligned \n',
#  'Armor Class 13 (natural armor) \n',
#  'Hit Points 136 (13d12 + 52) \n',
#  'Speed 50 ft. \n',
#  'Skills Perception +4 \n',
#  'Senses passive Perception 14 \n',
#  'Languages — \n',
#  'Challenge 8 (3,900 XP) \n',
#  'Actions \n',
#  'Doppelganger \n',
#  'Armor Class 14 \n',
#  'Hit Points 52 (8d8 + 16) \n',
#  'Speed 30 ft. \n',
#  'Skills Deception +6, Insight +3 \n',
#  'Condition Immunities charmed \n',
#  'Languages Common \n',
#  'Challenge 3 (700 XP) \n',
#  'Actions \n',
# ...
#  'Huge beast, unaligned \n',
#  'Armor Class 13 (natural armor) \n',
#  'Hit Points 126 (11d12 + 55) \n',
#  'Speed 0 ft., swim 50 ft. \n',
#  'Skills Perception +3 \n',
#  'Languages — \n',
#  'Challenge 5 (1,800 XP) \n',
#  'Actions \n',
#  'Giant Spider \n',
#  'Large beast, unaligned \n',
#  'Armor Class 14 (natural armor) \n',
#  'Hit Points 26 (4d10 + 4) \n',
#  'Speed 30 ft., climb 30 ft. \n',
#  'Skills Stealth +7 \n',
#  'Languages — \n',
#  'Challenge 1 (200 XP) \n',
#  'Actions \n',
#  'Giant Toad \n',
#  'Large beast, unaligned \n',
#  'Armor Class 11 \n',
#  'Hit Points 39 (6d10 + 6) \n',
#  'Speed 20 ft., swim 40 ft. \n',
#  'Languages — \n',
#  'Challenge 1 (200 XP) \n',
#  'Actions \n',
#  'Giant Vulture \n',
#  'Large beast, neutral evil \n',
#  'Armor Class 10 \n',
#  'Hit Points 22 (3d10 + 6) \n',
#  'Speed 10 ft., fly 60 ft. \n',
#  'Skills Perception +3 \n',
#  'Senses passive Perception 13 \n',
#  'Challenge 1 (200 XP) \n',
#  'Actions \n',
#  'Giant Wasp \n',
#  'Medium beast, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 13 (3d8) \n',
#  'Speed 10 ft., fly 50 ft. \n',
#  'Senses passive Perception 10 \n',
#  'Languages — \n',
#  'Challenge 1/2 (100 XP) \n',
#  'Actions \n',
#  'Giant Weasel \n',
#  'Medium beast, unaligned \n',
#  'Armor Class 13 \n',
#  'Hit Points 9 (2d8) \n',
#  'Speed 40 ft. \n',
#  'Skills Perception +3, Stealth +5 \n',
#  'Languages — \n',
#  'Challenge 1/8 (25 XP) \n',
#  'Actions \n',
#  'Giant Wolf Spider \n',
#  'Medium beast, unaligned \n',
#  'Armor Class 13 \n',
#  'Hit Points 11 (2d8 + 2) \n',
#  'Speed 40 ft., climb 40 ft. \n',
#  'Skills Perception +3, Stealth +7 \n',
#  'Languages — \n',
#  'Challenge 1/4 (50 XP) \n',
#  'Actions \n',
#  'Goat \n',
#  'Medium beast, unaligned \n',
#  'Armor Class 10 \n',
#  'Hit Points 4 (1d8) \n',
#  'Speed 40 ft. \n',
#  'Senses passive Perception 10 \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Hawk \n',
#  'Tiny beast, unaligned \n',
#  'Armor Class 13 \n',
#  'Hit Points 1 (1d4 − 1) \n',
#  'Speed 10 ft., fly 60 ft. \n',
#  'Skills Perception +4 \n',
#  'Senses passive Perception 14 \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Hunter Shark \n',
#  'Large beast, unaligned \n',
#  'Armor Class 12 (natural armor) \n',
#  'Hit Points 45 (6d10 + 12) \n',
#  'Speed 0 ft., swim 40 ft. \n',
#  'Skills Perception +2 \n',
#  'Languages — \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Hyena \n',
#  'Medium beast, unaligned \n',
#  'Armor Class 11 \n',
#  'Hit Points 5 (1d8 + 1) \n',
#  'Speed 50 ft. \n',
#  'Skills Perception +3 \n',
#  'Senses passive Perception 13 \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Jackal \n',
#  'Small beast, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 3 (1d6) \n',
#  'Speed 40 ft. \n',
#  'Skills Perception +3 \n',
#  'Senses passive Perception 13 \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Killer Whale \n',
#  'Huge beast, unaligned \n',
#  'Armor Class 12 (natural armor) \n',
#  'Hit Points 90 (12d12 + 12) \n',
#  'Speed 0 ft., swim 60 ft. \n',
#  'Skills Perception +3 \n',
#  'Languages — \n',
#  'Challenge 3 (700 XP) \n',
#  'Actions \n',
#  'Lion \n',
#  'Large beast, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 26 (4d10 + 4) \n',
#  'Speed 50 ft. \n',
#  'Skills Perception +3, Stealth +6 \n',
#  'Senses passive Perception 13 \n',
#  'Languages — \n',
#  'Challenge 1 (200 XP) \n',
#  'Actions \n',
#  'Lizard \n',
#  'Tiny beast, unaligned \n',
#  'Armor Class 10 \n',
#  'Hit Points 2 (1d4) \n',
#  'Speed 20 ft., climb 20 ft. \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Mammoth \n',
#  'Huge beast, unaligned \n',
#  'Armor Class 13 (natural armor) \n',
#  'Hit Points 126 (11d12 + 55) \n',
#  'Speed 40 ft. \n',
#  'Senses passive Perception 10 \n',
#  'Languages — \n',
#  'Challenge 6 (2,300 XP) \n',
#  'Actions \n',
#  'Mastiff \n',
#  'Medium beast, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 5 (1d8 + 1) \n',
#  'Speed 40 ft. \n',
#  'Skills Perception +3 \n',
#  'Senses passive Perception 13 \n',
#  'Languages — \n',
#  'Challenge 1/8 (25 XP) \n',
#  'Actions \n',
#  'Mule \n',
#  'Medium beast, unaligned \n',
#  'Armor Class 10 \n',
#  'Hit Points 11 (2d8 + 2) \n',
#  'Speed 40 ft. \n',
#  'Senses passive Perception 10 \n',
#  'Languages — \n',
#  'Challenge 1/8 (25 XP) \n',
#  'Actions \n',
#  'Octopus \n',
#  'Small beast, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 3 (1d6) \n',
#  'Speed 5 ft., swim 30 ft. \n',
#  'Skills Perception +2, Stealth +4 \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Owl \n',
#  'Tiny beast, unaligned \n',
#  'Armor Class 11 \n',
#  'Hit Points 1 (1d4 − 1) \n',
#  'Speed 5 ft., fly 60 ft. \n',
#  'Skills Perception +3, Stealth +3 \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Panther \n',
#  'Medium beast, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 13 (3d8) \n',
#  'Speed 50 ft., climb 40 ft. \n',
#  'Skills Perception +4, Stealth +6 \n',
#  'Senses passive Perception 14 \n',
#  'Languages — \n',
#  'Challenge 1/4 (50 XP) \n',
#  'Actions \n',
#  'Phase Spider \n',
#  'Large monstrosity, unaligned \n',
#  'Armor Class 13 (natural armor) \n',
#  'Hit Points 32 (5d10 + 5) \n',
#  'Speed 30 ft., climb 30 ft. \n',
#  'Skills Stealth +6 \n',
#  'Languages — \n',
#  'Challenge 3 (700 XP) \n',
#  'Actions \n',
#  'Poisonous Snake \n',
#  'Tiny beast, unaligned \n',
#  'Armor Class 13 \n',
#  'Hit Points 2 (1d4) \n',
#  'Speed 30 ft., swim 30 ft. \n',
#  'Languages — \n',
#  'Challenge 1/8 (25 XP) \n',
#  'Actions \n',
#  'Polar Bear \n',
#  'Large beast, unaligned \n',
#  'Armor Class 12 (natural armor) \n',
#  'Hit Points 42 (5d10 + 15) \n',
#  'Speed 40 ft., swim 30 ft. \n',
#  'Skills Perception +3 \n',
#  'Senses passive Perception 13 \n',
#  'Languages — \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Pony \n',
#  'Medium beast, unaligned \n',
#  'Armor Class 10 \n',
#  'Hit Points 11 (2d8 + 2) \n',
#  'Speed 40 ft. \n',
#  'Senses passive Perception 10 \n',
#  'Languages — \n',
#  'Challenge 1/8 (25 XP) \n',
#  'Actions \n',
#  'Quipper \n',
#  'Tiny beast, unaligned \n',
#  'Armor Class 13 \n',
#  'Hit Points 1 (1d4 − 1) \n',
#  'Speed 0 ft., swim 40 ft. \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Rat \n',
#  'Tiny beast, unaligned \n',
#  'Armor Class 10 \n',
#  'Hit Points 1 (1d4 − 1) \n',
#  'Speed 20 ft. \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Raven \n',
#  'Tiny beast, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 1 (1d4 − 1) \n',
#  'Speed 10 ft., fly 50 ft. \n',
#  'Skills Perception +3 \n',
#  'Senses passive Perception 13 \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Reef Shark \n',
#  'Medium beast, unaligned \n',
#  'Armor Class 12 (natural armor) \n',
#  'Hit Points 22 (4d8 + 4) \n',
#  'Speed 0 ft., swim 40 ft. \n',
#  'Skills Perception +2 \n',
#  'Languages — \n',
#  'Challenge 1/2 (100 XP) \n',
#  'Actions \n',
#  'Rhinoceros \n',
#  'Large beast, unaligned \n',
#  'Armor Class 11 (natural armor) \n',
#  'Hit Points 45 (6d10 + 12) \n',
#  'Speed 40 ft. \n',
#  'Senses passive Perception 11 \n',
#  'Languages — \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Riding Horse \n',
#  'Large beast, unaligned \n',
#  'Armor Class 10 \n',
#  'Hit Points 13 (2d10 + 2) \n',
#  'Speed 60 ft. \n',
#  'Senses passive Perception 10 \n',
#  'Languages — \n',
#  'Challenge 1/4 (50 XP) \n',
#  'Actions \n',
#  'Saber-\xad‐Toothed Tiger \n',
#  'Large beast, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 52 (7d10 + 14) \n',
#  'Speed 40 ft. \n',
#  'Skills Perception +3, Stealth +6 \n',
#  'Senses passive Perception 13 \n',
#  'Languages — \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Scorpion \n',
#  'Tiny beast, unaligned \n',
#  'Armor Class 11 (natural armor) \n',
#  'Hit Points 1 (1d4 − 1) \n',
#  'Speed 10 ft. \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Sea Horse \n',
#  'Tiny beast, unaligned \n',
#  'Armor Class 11 \n',
#  'Hit Points 1 (1d4 − 1) \n',
#  'Speed 0 ft., swim 20 ft. \n',
#  'Senses passive Perception 10 \n',
#  'Languages — \n',
#  'Challenge 0 (0 XP) \n',
#  'Spider \n',
#  'Tiny beast, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 1 (1d4 − 1) \n',
#  'Speed 20 ft., climb 20 ft. \n',
#  'Skills Stealth +4 \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Swarm of Bats \n',
#  'Medium swarm of Tiny beasts, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 22 (5d8) \n',
#  'Speed 0 ft., fly 30 ft. \n',
#  'Languages — \n',
#  'Challenge 1/4 (50 XP) \n',
#  'Actions \n',
#  'Swarm of Insects \n',
#  'Medium swarm of Tiny beasts, unaligned \n',
#  'Armor Class 12 (natural armor) \n',
#  'Hit Points 22 (5d8) \n',
#  'Speed 20 ft., climb 20 ft. \n',
#  'Languages — \n',
#  'Challenge 1/2 (100 XP) \n',
#  'Actions \n',
#  'Swarm of Poisonous Snakes \n',
#  'Medium swarm of Tiny beasts, unaligned \n',
#  'Armor Class 14 \n',
#  'Hit Points 36 (8d8) \n',
#  'Speed 30 ft., swim 30 ft. \n',
#  'Languages — \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Swarm of Quippers \n',
#  'Medium swarm of Tiny beasts, unaligned \n',
#  'Armor Class 13 \n',
#  'Hit Points 28 (8d8 − 8) \n',
#  'Speed 0 ft., swim 40 ft. \n',
#  'Languages — \n',
#  'Challenge 1 (200 XP) \n',
#  'Actions \n',
#  'Swarm of Rats \n',
#  'Medium swarm of Tiny beasts, unaligned \n',
#  'Armor Class 10 \n',
#  'Hit Points 24 (7d8 − 7) \n',
#  'Speed 30 ft. \n',
#  'Languages — \n',
#  'Challenge 1/4 (50 XP) \n',
#  'Actions \n',
#  'Swarm of Ravens \n',
#  'Medium swarm of Tiny beasts, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 24 (7d8 − 7) \n',
#  'Speed 10 ft., fly 50 ft. \n',
#  'Skills Perception +5 \n',
#  'Senses passive Perception 15 \n',
#  'Languages — \n',
#  'Challenge 1/4 (50 XP) \n',
#  'Actions \n',
#  'Variant: Insect Swarms \n',
#  'Tiger \n',
#  'Large beast, unaligned \n',
#  'Armor Class 12 \n',
#  'Hit Points 37 (5d10 + 10) \n',
#  'Speed 40 ft. \n',
#  'Skills Perception +3, Stealth +6 \n',
#  'Languages — \n',
#  'Challenge 1 (200 XP) \n',
#  'Actions \n',
#  'Vulture \n',
#  'Medium beast, unaligned \n',
#  'Armor Class 10 \n',
#  'Hit Points 5 (1d8 + 1) \n',
#  'Speed 10 ft., fly 50 ft. \n',
#  'Skills Perception +3 \n',
#  'Senses passive Perception 13 \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Warhorse \n',
#  'Large beast, unaligned \n',
#  'Armor Class 11 \n',
#  'Hit Points 19 (3d10 + 3) \n',
#  'Speed 60 ft. \n',
#  'Senses passive Perception 11 \n',
#  'Languages — \n',
#  'Challenge 1/2 (100 XP) \n',
#  'Actions \n',
#  'Weasel \n',
#  'Tiny beast, unaligned \n',
#  'Armor Class 13 \n',
#  'Hit Points 1 (1d4 − 1) \n',
#  'Speed 30 ft. \n',
#  'Skills Perception +3, Stealth +5 \n',
#  'Senses passive Perception 13 \n',
#  'Languages — \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Winter Wolf \n',
#  'Large monstrosity, neutral evil \n',
#  'Armor Class 13 (natural armor) \n',
#  'Hit Points 75 (10d10 + 20) \n',
#  'Speed 50 ft. \n',
#  'Skills Perception +5, Stealth +3 \n',
#  'Damage Immunities cold \n',
#  'Senses passive Perception 15 \n',
#  'Languages Common, Giant, Winter Wolf \n',
#  'Challenge 3 (700 XP) \n',
#  'Actions \n',
#  'Wolf \n',
#  'Medium beast, unaligned \n',
#  'Armor Class 13 (natural armor) \n',
#  'Hit Points 11 (2d8 + 2) \n',
#  'Speed 40 ft. \n',
#  'Skills Perception +3, Stealth +4 \n',
#  'Senses passive Perception 13 \n',
#  'Languages — \n',
#  'Challenge 1/4 (50 XP) \n',
#  'Actions \n',
#  'Worg \n',
#  'Large monstrosity, neutral evil \n',
#  'Armor Class 13 (natural armor) \n',
#  'Hit Points 26 (4d10 + 4) \n',
#  'Speed 50 ft. \n',
#  'Skills Perception +4 \n',
#  'Languages Goblin, Worg \n',
#  'Challenge 1/2 (100 XP) \n',
#  'Actions \n',
#  'Appendix MM-B: \nNonplayer \nCharacters \n',
#  'Customizing NPCs \n',
#  'Acolyte \n',
#  'Armor Class 10 \n',
#  'Hit Points 9 (2d8) \n',
#  'Speed 30 ft. \n',
#  'Skills Medicine +4, Religion +2 \n',
#  'Senses passive Perception 12 \n',
#  'Challenge 1/4 (50 XP) \n',
#  'Actions \n',
#  'Archmage \n',
#  'Armor Class 12 (15 with mage armor) \n',
#  'Hit Points 99 (18d8 + 18) \n',
#  'Speed 30 ft. \n',
#  'Saving Throws Int +9, Wis +6 \n',
#  'Skills Arcana +13, History +13 \n',
#  'Senses passive Perception 12 \n',
#  'Languages any six languages \n',
#  'Challenge 12 (8,400 XP) \n',
#  'Actions\n',
#  'Assassin \n',
#  'Armor Class 15 (studded leather) \n',
#  'Hit Points 78 (12d8 + 24) \n',
#  'Speed 30 ft. \n',
#  'Saving Throws Dex +6, Int +4 \n',
#  'Damage Resistances poison \n',
#  'Senses passive Perception 13 \n',
#  'Challenge 8 (3,900 XP) \n',
#  'Actions \n',
#  'Bandit \n',
#  'Armor Class 12 (leather armor) \n',
#  'Hit Points 11 (2d8 + 2) \n',
#  'Speed 30 ft. \n',
#  'Senses passive Perception 10 \n',
#  'Challenge 1/8 (25 XP) \n',
#  'Actions \n',
#  'Bandit Captain \n',
#  'Armor Class 15 (studded leather) \n',
#  'Hit Points 65 (10d8 + 20) \n',
#  'Speed 30 ft. \n',
#  'Saving Throws Str +4, Dex +5, Wis +2 \n',
#  'Skills Athletics +4, Deception +4 \n',
#  'Senses passive Perception 10 \n',
#  'Languages any two languages \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Reactions \n',
#  'Berserker \n',
#  'Armor Class 13 (hide armor) \n',
#  'Hit Points 67 (9d8 + 27) \n',
#  'Speed 30 ft. \n',
#  'Senses passive Perception 10 \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Commoner \n',
#  'Armor Class 10 \n',
#  'Hit Points 4 (1d8) \n',
#  'Speed 30 ft. \n',
#  'Senses passive Perception 10 \n',
#  'Challenge 0 (10 XP) \n',
#  'Actions \n',
#  'Cultist \n',
#  'Armor Class 12 (leather armor) \n',
#  'Hit Points 9 (2d8) \n',
#  'Speed 30 ft. \n',
#  'Skills Deception +2, Religion +2 \n',
#  'Senses passive Perception 10 \n',
#  'Challenge 1/8 (25 XP) \n',
#  'Actions \n',
#  'Cult Fanatic \n',
#  'Armor Class 13 (leather armor) \n',
#  'Hit Points 33 (6d8 + 6) \n',
#  'Speed 30 ft. \n',
#  'Senses passive Perception 11 \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Druid \n',
#  'Armor Class 11 (16 with barkskin) \n',
#  'Hit Points 27 (5d8 + 5) \n',
#  'Speed 30 ft. \n',
#  'Senses passive Perception 14 \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Gladiator \n',
#  'Hit Points 112 (15d8 + 45) \n',
#  'Speed 30 ft. \n',
#  'Saving Throws Str +7, Dex +5, Con +6 \n',
#  'Skills Athletics +10, Intimidation +5 \n',
#  'Senses passive Perception 11 \n',
#  'Challenge 5 (1,800 XP) \n',
#  'Actions \n',
#  'Reactions \n',
#  'Guard \n',
#  'Armor Class 16 (chain shirt, shield) \n',
#  'Hit Points 11 (2d8 + 2) \n',
#  'Speed 30 ft. \n',
#  'Skills Perception +2 \n',
#  'Senses passive Perception 12 \n',
#  'Challenge 1/8 (25 XP) \n',
#  'Actions \n',
#  'Knight \n',
#  'Armor Class 18 (plate) \n',
#  'Hit Points 52 (8d8 + 16) \n',
#  'Speed 30 ft. \n',
#  'Saving Throws Con +4, Wis +2 \n',
#  'Senses passive Perception 10 \n',
#  'Challenge 3 (700 XP) \n',
#  'Actions \n',
#  'Reactions \n',
#  'Mage \n',
#  'Armor Class 12 (15 with mage armor) \n',
#  'Hit Points 40 (9d8) \n',
#  'Speed 30 ft. \n',
#  'Saving Throws Int +6, Wis +4 \n',
#  'Skills Arcana +6, History +6 \n',
#  'Senses passive Perception 11 \n',
#  'Languages any four languages \n',
#  'Challenge 6 (2,300 XP) \n',
#  'Actions \n',
#  'Noble \n',
#  'Armor Class 15 (breastplate) \n',
#  'Hit Points 9 (2d8) \n',
#  'Speed 30 ft. \n',
#  'Senses passive Perception 12 \n',
#  'Languages any two languages \n',
#  'Challenge 1/8 (25 XP) \n',
#  'Actions \n',
#  'Reactions \n',
#  'Priest \n',
#  'Armor Class 13 (chain shirt) \n',
#  'Hit Points 27 (5d8 + 5) \n',
#  'Speed 25 ft. \n',
#  'Senses passive Perception 13 \n',
#  'Languages any two languages \n',
#  'Challenge 2 (450 XP) \n',
#  'Actions \n',
#  'Scout \n',
#  'Armor Class 13 (leather armor) \n',
#  'Hit Points 16 (3d8 + 3) \n',
#  'Speed 30 ft. \n',
#  'Senses passive Perception 15 \n',
#  'Challenge 1/2 (100 XP) \n',
#  'Actions \n',
#  'Spy \n',
#  'Armor Class 12 \n',
#  'Hit Points 27 (6d8) \n',
#  'Speed 30 ft. \n',
#  'Senses passive Perception 16 \n',
#  'Languages any two languages \n',
#  'Challenge 1 (200 XP) \n',
#  'Actions \n',
#  'Thug \n',
#  'Armor Class 11 (leather armor) \n',
#  'Hit Points 32 (5d8 + 10) \n',
#  'Speed 30 ft. \n',
#  'Skills Intimidation +2 \n',
#  'Senses passive Perception 10 \n',
#  'Challenge 1/2 (100 XP) \n',
#  'Actions \n',
#  'Tribal Warrior \n',
#  'Armor Class 12 (hide armor) \n',
#  'Hit Points 11 (2d8 + 2) \n',
#  'Speed 30 ft. \n',
#  'Senses passive Perception 10 \n',
#  'Languages any one language \n',
#  'Challenge 1/8 (25 XP) \n',
#  'Actions \n',
#  'Veteran \n',
#  'Armor Class 17 (splint) \n',
#  'Hit Points 58 (9d8 + 18) \n',
#  'Speed 30 ft. \n',
#  'Skills Athletics +5, Perception +2 \n',
#  'Senses passive Perception 12 \n',
#  'Challenge 3 (700 XP) \n',
#  'Actions \n']

# %% [markdown]
# ... okay.  The above approach sucks.  It's unreliable.  Positioning isn't a good enough indicator of a section header.

# %% [markdown]
# ## Alternate approach - find heads by font sizes
# Are the font colors / sizes predictable enough?

# %%
# ('Races'): 'GillSans-SemiBold', size ~25.920000076293945, color 9647668
CHAPTER = { 'font': 'GillSans-SemiBold', 'size': 25.920000076293945, 'color': 9647668 }

# ('Dwarf'): 'GillSans-SemiBold', size 18, color 9647668
SECTION = { 'font': 'GillSans-SemiBold', 'size': 18, 'color': 9647668 }

# ('Racial Traits'): 'GillSans-SemiBold', size ~13.920000076293945, color 9647668
SUBSECTION = { 'font': 'GillSans-SemiBold', 'size': 13.920000076293945, 'color': 9647668 }

# ('Ability Score Increase'): 'GillSans-SemiBold', size 12, color 9647668
SUBSUBSECTION = { 'font': 'GillSans-SemiBold', 'size': 12, 'color': 9647668 }

# TODO: term & definition - e.g., Adventuring Gear with the bold, italic lead in to the paragraph
# TODO: table header / capturing tables
# TODO: sidebars like "Self-Sufficiency" on page 73E
# TODO: handle two back-to-back sections, like "Using Ablility" followed by "Scores" on 76

# TODO: monster headers for individual monster stat blocks

# %%
for i, page in enumerate(doc):
    d = page.get_text('dict')
    blocks = d['blocks']
    for block in blocks:
        if "lines" in block.keys():
            spans = block['lines']
            for span in spans:
                data = span['spans']
                for lines in data:
                    if lines['font'] == CHAPTER['font'] and lines['size'] == CHAPTER['size'] and lines['color'] == CHAPTER['color']:
                        print(f"CHAPTER: {lines['text']}")
                    if lines['font'] == SECTION['font'] and lines['size'] == SECTION['size'] and lines['color'] == SECTION['color']:
                        print(f"  SECTION: {lines['text']}")
                    if lines['font'] == SUBSECTION['font'] and lines['size'] == SUBSECTION['size'] and lines['color'] == SUBSECTION['color']:
                        print(f"    SUBSECTION: {lines['text']}")
                    if lines['font'] == SUBSUBSECTION['font'] and lines['size'] == SUBSUBSECTION['size'] and lines['color'] == SUBSUBSECTION['color']:
                        print(f"      SUB-SUBSECTION: {lines['text']}")
# Out:
# CHAPTER: Races
#     SUBSECTION: Racial Traits
#       SUB-SUBSECTION: Ability Score Increase
#       SUB-SUBSECTION: Age
#       SUB-SUBSECTION: Alignment
#       SUB-SUBSECTION: Size
#       SUB-SUBSECTION: Speed
#       SUB-SUBSECTION: Languages
#       SUB-SUBSECTION: Subraces
#   SECTION: Dwarf
#     SUBSECTION: Dwarf Traits
#       SUB-SUBSECTION: Hill Dwarf
#   SECTION: Elf
#     SUBSECTION: Elf Traits
#       SUB-SUBSECTION: High Elf
#   SECTION: Halfling
#     SUBSECTION: Halfling Traits
#       SUB-SUBSECTION: Lightfoot
#   SECTION: Human
#     SUBSECTION: Human Traits
#   SECTION: Dragonborn
#     SUBSECTION: Dragonborn Traits
#   SECTION: Gnome
#     SUBSECTION: Gnome Traits
#       SUB-SUBSECTION: Rock Gnome
#   SECTION: Half-Elf
#     SUBSECTION: Half-Elf Traits
#   SECTION: Half-Orc
#     SUBSECTION: Half-Orc Traits
#   SECTION: Tiefling
#     SUBSECTION: Tiefling Traits
# CHAPTER: Barbarian
#   SECTION: Class Features
#       SUB-SUBSECTION: Hit Points
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Equipment
#     SUBSECTION: Rage
#     SUBSECTION: Unarmored Defense
#     SUBSECTION: Reckless Attack
#     SUBSECTION: Danger Sense
#     SUBSECTION: Primal Path
#     SUBSECTION: Ability Score Improvement
#     SUBSECTION: Extra Attack
#     SUBSECTION: Fast Movement
#     SUBSECTION: Feral Instinct
#     SUBSECTION: Brutal Critical
#     SUBSECTION: Relentless Rage
#     SUBSECTION: Persistent Rage
#     SUBSECTION: Indomitable Might
#     SUBSECTION: Primal Champion
#     SUBSECTION: Path of the Berserker
#       SUB-SUBSECTION: Frenzy
#       SUB-SUBSECTION: Mindless Rage
#       SUB-SUBSECTION: Intimidating Presence
#       SUB-SUBSECTION: Retaliation
# CHAPTER: Bard
#   SECTION: Class Features
#       SUB-SUBSECTION: Hit Points
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Equipment
#     SUBSECTION: Spellcasting
#       SUB-SUBSECTION: Cantrips
#       SUB-SUBSECTION: Spell Slots
#       SUB-SUBSECTION: Spells Known of 1st Level and Higher
#       SUB-SUBSECTION: Spellcasting Ability
#       SUB-SUBSECTION: Ritual Casting
#       SUB-SUBSECTION: Spellcasting Focus
#     SUBSECTION: Bardic Inspiration
#     SUBSECTION: Jack of All Trades
#     SUBSECTION: Song of Rest
#     SUBSECTION: Bard College
#     SUBSECTION: Expertise
#     SUBSECTION: Ability Score Improvement
#     SUBSECTION: Font of Inspiration
#     SUBSECTION: Countercharm
#     SUBSECTION: Magical Secrets
#     SUBSECTION: Superior Inspiration
#     SUBSECTION: College of Lore
#       SUB-SUBSECTION: Bonus Proficiencies
#       SUB-SUBSECTION: Cutting Words
#       SUB-SUBSECTION: Additional Magical Secrets
#       SUB-SUBSECTION: Peerless Skill
# CHAPTER: Cleric
#   SECTION: Class Features
#       SUB-SUBSECTION: Hit Points
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Equipment
#     SUBSECTION: Spellcasting
#       SUB-SUBSECTION: Cantrips
#       SUB-SUBSECTION: Preparing and Casting Spells
#       SUB-SUBSECTION: Spellcasting Ability
#       SUB-SUBSECTION: Ritual Casting
#       SUB-SUBSECTION: Spellcasting Focus
#     SUBSECTION: Divine Domain
#       SUB-SUBSECTION: Domain Spells
#     SUBSECTION: Channel Divinity
#       SUB-SUBSECTION: Channel Divinity: Turn Undead
#     SUBSECTION: Ability Score Improvement
#     SUBSECTION: Destroy Undead
#     SUBSECTION: Divine Intervention
#     SUBSECTION: Life Domain
#       SUB-SUBSECTION: Bonus Proficiency
#       SUB-SUBSECTION: Disciple of Life
#       SUB-SUBSECTION: Channel Divinity: Preserve Life
#       SUB-SUBSECTION: Blessed Healer
#       SUB-SUBSECTION: Divine Strike
#       SUB-SUBSECTION: Supreme Healing
# CHAPTER: Druid
#   SECTION: Class Features
#       SUB-SUBSECTION: Hit Points
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Equipment
#     SUBSECTION: Druidic
#     SUBSECTION: Spellcasting
#       SUB-SUBSECTION: Cantrips
#       SUB-SUBSECTION: Preparing and Casting Spells
#       SUB-SUBSECTION: Spellcasting Ability
#       SUB-SUBSECTION: Ritual Casting
#       SUB-SUBSECTION: Spellcasting Focus
#     SUBSECTION: Wild Shape
#     SUBSECTION: Druid Circle
#     SUBSECTION: Ability Score Improvement
#     SUBSECTION: Timeless Body
#     SUBSECTION: Beast Spells
#     SUBSECTION: Archdruid
#     SUBSECTION: Circle of the Land
#       SUB-SUBSECTION: Bonus Cantrip
#       SUB-SUBSECTION: Natural Recovery
#       SUB-SUBSECTION: Circle Spells
#       SUB-SUBSECTION: Land’s Stride
#       SUB-SUBSECTION: Nature’s Ward
#       SUB-SUBSECTION: Nature’s Sanctuary
# CHAPTER: Fighter
#   SECTION: Class Features
#       SUB-SUBSECTION: Hit Points
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Equipment
#     SUBSECTION: Fighting Style
#       SUB-SUBSECTION: Archery
#       SUB-SUBSECTION: Defense
#       SUB-SUBSECTION: Dueling
#       SUB-SUBSECTION: Great Weapon Fighting
#       SUB-SUBSECTION: Protection
#       SUB-SUBSECTION: Two-Weapon Fighting
#     SUBSECTION: Second Wind
#     SUBSECTION: Action Surge
#     SUBSECTION: Martial Archetype
#     SUBSECTION: Ability Score Improvement
#     SUBSECTION: Extra Attack
#     SUBSECTION: Indomitable
#   SECTION: Martial Archetypes
#     SUBSECTION: Champion
#       SUB-SUBSECTION: Improved Critical
#       SUB-SUBSECTION: Remarkable Athlete
#       SUB-SUBSECTION: Additional Fighting Style
#       SUB-SUBSECTION: Superior Critical
#       SUB-SUBSECTION: Survivor
# CHAPTER: Monk
#   SECTION: Class Features
#       SUB-SUBSECTION: Hit Points
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Equipment
#     SUBSECTION: Unarmored Defense
#     SUBSECTION: Martial Arts
#     SUBSECTION: Ki
#       SUB-SUBSECTION: Flurry of Blows
#       SUB-SUBSECTION: Patient Defense
#       SUB-SUBSECTION: Step of the Wind
#     SUBSECTION: Unarmored Movement
#     SUBSECTION: Monastic Tradition
#     SUBSECTION: Deflect Missiles
#     SUBSECTION: Ability Score Improvement
#     SUBSECTION: Slow Fall
#     SUBSECTION: Extra Attack
#     SUBSECTION: Stunning Strike
#     SUBSECTION: Ki-Empowered Strikes
#     SUBSECTION: Evasion
#     SUBSECTION: Stillness of Mind
#     SUBSECTION: Purity of Body
#     SUBSECTION: Tongue of the Sun and Moon
#     SUBSECTION: Diamond Soul
#     SUBSECTION: Timeless Body
#     SUBSECTION: Empty Body
#     SUBSECTION: Perfect Self
#   SECTION: Monastic Traditions
#     SUBSECTION: Way of the Open Hand
#       SUB-SUBSECTION: Open Hand Technique
#       SUB-SUBSECTION: Wholeness of Body
#       SUB-SUBSECTION: Tranquility
#       SUB-SUBSECTION: Quivering Palm
# CHAPTER: Paladin
#   SECTION: Class Features
#       SUB-SUBSECTION: Hit Points
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Equipment
#     SUBSECTION: Divine Sense
#     SUBSECTION: Lay on Hands
#     SUBSECTION: Fighting Style
#       SUB-SUBSECTION: Defense
#       SUB-SUBSECTION: Dueling
#       SUB-SUBSECTION: Great Weapon Fighting
#       SUB-SUBSECTION: Protection
#     SUBSECTION: Spellcasting
#       SUB-SUBSECTION: Preparing and Casting Spells
#       SUB-SUBSECTION: Spellcasting Ability
#       SUB-SUBSECTION: Spellcasting Focus
#     SUBSECTION: Divine Smite
#     SUBSECTION: Divine Health
#     SUBSECTION: Sacred Oath
#       SUB-SUBSECTION: Oath Spells
#       SUB-SUBSECTION: Channel Divinity
#     SUBSECTION: Ability Score Improvement
#     SUBSECTION: Extra Attack
#     SUBSECTION: Aura of Protection
#     SUBSECTION: Aura of Courage
#     SUBSECTION: Improved Divine Smite
#     SUBSECTION: Cleansing Touch
#   SECTION: Sacred Oaths
#     SUBSECTION: Oath of Devotion
#       SUB-SUBSECTION: Tenets of Devotion
#       SUB-SUBSECTION: Oath Spells
#       SUB-SUBSECTION: Channel Divinity
#       SUB-SUBSECTION: Aura of Devotion
#       SUB-SUBSECTION: Purity of Spirit
#       SUB-SUBSECTION: Holy Nimbus
# CHAPTER: Ranger
#   SECTION: Class Features
#       SUB-SUBSECTION: Hit Points
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Equipment
#     SUBSECTION: Favored Enemy
#     SUBSECTION: Natural Explorer
#     SUBSECTION: Fighting Style
#       SUB-SUBSECTION: Archery
#       SUB-SUBSECTION: Defense
#       SUB-SUBSECTION: Dueling
#       SUB-SUBSECTION: Two-Weapon Fighting
#     SUBSECTION: Spellcasting
#       SUB-SUBSECTION: Spell Slots
#       SUB-SUBSECTION: Spells Known of 1st Level and Higher
#       SUB-SUBSECTION: Spellcasting Ability
#     SUBSECTION: Ranger Archetype
#     SUBSECTION: Primeval Awareness
#     SUBSECTION: Ability Score Improvement
#     SUBSECTION: Extra Attack
#     SUBSECTION: Land’s Stride
#     SUBSECTION: Hide in Plain Sight
#     SUBSECTION: Vanish
#     SUBSECTION: Feral Senses
#     SUBSECTION: Foe Slayer
#   SECTION: Ranger Archetypes
#     SUBSECTION: Hunter
#       SUB-SUBSECTION: Hunter’s Prey
#       SUB-SUBSECTION: Defensive Tactics
#       SUB-SUBSECTION: Multiattack
#       SUB-SUBSECTION: Superior Hunter’s Defense
# CHAPTER: Rogue
#   SECTION: Class Features
#       SUB-SUBSECTION: Hit Points
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Equipment
#     SUBSECTION: Expertise
#     SUBSECTION: Sneak Attack
#     SUBSECTION: Thieves’ Cant
#     SUBSECTION: Cunning Action
#     SUBSECTION: Roguish Archetype
#     SUBSECTION: Ability Score Improvement
#     SUBSECTION: Uncanny Dodge
#     SUBSECTION: Evasion
#     SUBSECTION: Reliable Talent
#     SUBSECTION: Blindsense
#     SUBSECTION: Slippery Mind
#     SUBSECTION: Elusive
#     SUBSECTION: Stroke of Luck
#   SECTION: Roguish Archetypes
#     SUBSECTION: Thief
#       SUB-SUBSECTION: Fast Hands
#       SUB-SUBSECTION: Second-Story Work
#       SUB-SUBSECTION: Supreme Sneak
#       SUB-SUBSECTION: Use Magic Device
#       SUB-SUBSECTION: Thief’s Reflexes
# CHAPTER: Sorcerer
#   SECTION: Class Features
#       SUB-SUBSECTION: Hit Points
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Equipment
#     SUBSECTION: Spellcasting
#       SUB-SUBSECTION: Cantrips
#       SUB-SUBSECTION: Spell Slots
#       SUB-SUBSECTION: Spells Known of 1st Level and Higher
#       SUB-SUBSECTION: Spellcasting Ability
#       SUB-SUBSECTION: Spellcasting Focus
#     SUBSECTION: Sorcerous Origin
#     SUBSECTION: Font of Magic
#       SUB-SUBSECTION: Sorcery Points
#       SUB-SUBSECTION: Flexible Casting
#     SUBSECTION: Metamagic
#       SUB-SUBSECTION: Careful Spell
#       SUB-SUBSECTION: Distant Spell
#       SUB-SUBSECTION: Empowered Spell
#       SUB-SUBSECTION: Extended Spell
#       SUB-SUBSECTION: Heightened Spell
#       SUB-SUBSECTION: Quickened Spell
#       SUB-SUBSECTION: Subtle Spell
#       SUB-SUBSECTION: Twinned Spell
#     SUBSECTION: Ability Score Improvement
#     SUBSECTION: Sorcerous Restoration
#   SECTION: Sorcerous Origins
#     SUBSECTION: Draconic Bloodline
#       SUB-SUBSECTION: Dragon Ancestor
#       SUB-SUBSECTION: Draconic Resilience
#       SUB-SUBSECTION: Elemental Affinity
#       SUB-SUBSECTION: Dragon Wings
#       SUB-SUBSECTION: Draconic Presence
# CHAPTER: Warlock
#   SECTION: Class Features
#       SUB-SUBSECTION: Hit Points
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Equipment
#     SUBSECTION: Otherworldly Patron
#     SUBSECTION: Pact Magic
#       SUB-SUBSECTION: Cantrips
#       SUB-SUBSECTION: Spell Slots
#       SUB-SUBSECTION: Spells Known of 1st Level and Higher
#       SUB-SUBSECTION: Spellcasting Ability
#       SUB-SUBSECTION: Spellcasting Focus
#     SUBSECTION: Eldritch Invocations
#     SUBSECTION: Pact Boon
#       SUB-SUBSECTION: Pact of the Chain
#       SUB-SUBSECTION: Pact of the Blade
#       SUB-SUBSECTION: Pact of the Tome
#     SUBSECTION: Ability Score Improvement
#     SUBSECTION: Mystic Arcanum
#     SUBSECTION: Eldritch Master
#   SECTION: Eldritch Invocations
#       SUB-SUBSECTION: Agonizing Blast
#       SUB-SUBSECTION: Armor of Shadows
#       SUB-SUBSECTION: Ascendant Step
#       SUB-SUBSECTION: Beast Speech
#       SUB-SUBSECTION: Beguiling Influence
#       SUB-SUBSECTION: Bewitching Whispers
#       SUB-SUBSECTION: Book of Ancient Secrets
#       SUB-SUBSECTION: Chains of Carceri
#       SUB-SUBSECTION: Devil’s Sight
#       SUB-SUBSECTION: Dreadful Word
#       SUB-SUBSECTION: Eldritch Sight
#       SUB-SUBSECTION: Eldritch Spear
#       SUB-SUBSECTION: Eyes of the Rune Keeper
#       SUB-SUBSECTION: Fiendish Vigor
#       SUB-SUBSECTION: Gaze of Two Minds
#       SUB-SUBSECTION: Lifedrinker
#       SUB-SUBSECTION: Mask of Many Faces
#       SUB-SUBSECTION: Master of Myriad Forms
#       SUB-SUBSECTION: Minions of Chaos
#       SUB-SUBSECTION: Mire the Mind
#       SUB-SUBSECTION: Misty Visions
#       SUB-SUBSECTION: One with Shadows
#       SUB-SUBSECTION: Otherworldly Leap
#       SUB-SUBSECTION: Repelling Blast
#       SUB-SUBSECTION: Sculptor of Flesh
#       SUB-SUBSECTION: Sign of Ill Omen
#       SUB-SUBSECTION: Thief of Five Fates
#       SUB-SUBSECTION: Thirsting Blade
#       SUB-SUBSECTION: Visions of Distant Realms
#       SUB-SUBSECTION: Voice of the Chain Master
#       SUB-SUBSECTION: Whispers of the Grave
#       SUB-SUBSECTION: Witch Sight
#   SECTION: Otherworldly Patrons
#     SUBSECTION: The Fiend
#       SUB-SUBSECTION: Expanded Spell List
#       SUB-SUBSECTION: Dark One’s Blessing
#       SUB-SUBSECTION: Dark One’s Own Luck
#       SUB-SUBSECTION: Fiendish Resilience
#       SUB-SUBSECTION: Hurl Through Hell
# CHAPTER: Wizard
#   SECTION: Class Features
#       SUB-SUBSECTION: Hit Points
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Equipment
#     SUBSECTION: Spellcasting
#       SUB-SUBSECTION: Cantrips
#       SUB-SUBSECTION: Spellbook
#       SUB-SUBSECTION: Preparing and Casting Spells
#       SUB-SUBSECTION: Spellcasting Ability
#       SUB-SUBSECTION: Ritual Casting
#       SUB-SUBSECTION: Spellcasting Focus
#       SUB-SUBSECTION: Learning Spells of 1st Level and Higher
#     SUBSECTION: Arcane Recovery
#     SUBSECTION: Arcane Tradition
#     SUBSECTION: Ability Score Improvement
#     SUBSECTION: Spell Mastery
#     SUBSECTION: Signature Spells
#   SECTION: Arcane Traditions
#     SUBSECTION: School of Evocation
#       SUB-SUBSECTION: Evocation Savant
#       SUB-SUBSECTION: Sculpt Spells
#       SUB-SUBSECTION: Potent Cantrip
#       SUB-SUBSECTION: Empowered Evocation
#       SUB-SUBSECTION: Overchannel
# CHAPTER: Beyond 1st Level
#   SECTION: Multiclassing
#     SUBSECTION: Prerequisites
#     SUBSECTION: Experience Points
#     SUBSECTION: Hit Points and Hit Dice
#     SUBSECTION: Proficiency Bonus
#     SUBSECTION: Proficiencies
#     SUBSECTION: Class Features
#       SUB-SUBSECTION: Channel Divinity
#       SUB-SUBSECTION: Extra Attack
#       SUB-SUBSECTION: Unarmored Defense
#       SUB-SUBSECTION: Spellcasting
#   SECTION: Alignment
#       SUB-SUBSECTION: Alignment in the Multiverse
#   SECTION: Languages
#   SECTION: Inspiration
#     SUBSECTION: Gaining Inspiration
#     SUBSECTION: Using Inspiration
#   SECTION: Backgrounds
#       SUB-SUBSECTION: Proficiencies
#       SUB-SUBSECTION: Languages
#       SUB-SUBSECTION: Equipment
#       SUB-SUBSECTION: Suggested Characteristics
#       SUB-SUBSECTION: Customizing a Background
#     SUBSECTION: Acolyte
#       SUB-SUBSECTION: Feature: Shelter of the Faithful
#       SUB-SUBSECTION: Suggested Characteristics
# CHAPTER: Equipment
#   SECTION: Selling Treasure
#   SECTION: Armor
#     SUBSECTION: Light Armor
#     SUBSECTION: Medium Armor
#     SUBSECTION: Heavy Armor
#     SUBSECTION: Getting Into and Out of Armor
#   SECTION: Weapons
#     SUBSECTION: Weapon Proficiency
#     SUBSECTION: Weapon Properties
#       SUB-SUBSECTION: Improvised Weapons
#       SUB-SUBSECTION: Silvered Weapons
#       SUB-SUBSECTION: Special Weapons
#   SECTION: Adventuring Gear
#   SECTION: Tools
#   SECTION: Mounts and Vehicles
#   SECTION: Trade Goods
#   SECTION: Expenses
#     SUBSECTION: Lifestyle Expenses
#     SUBSECTION: Food, Drink, and Lodging
#     SUBSECTION: Services
#     SUBSECTION: Spellcasting Services
# CHAPTER: Feats
#     SUBSECTION: Grappler
# CHAPTER: Using Ability
# CHAPTER: Scores
#   SECTION: Ability Scores and Modifiers
#   SECTION: Advantage and
#   SECTION: Disadvantage
#   SECTION: Proficiency Bonus
#   SECTION: Ability Checks
#     SUBSECTION: Contests
#     SUBSECTION: Skills
#       SUB-SUBSECTION: Strength
#       SUB-SUBSECTION: Dexterity
#       SUB-SUBSECTION: Intelligence
#       SUB-SUBSECTION: Wisdom
#       SUB-SUBSECTION: Charisma
#       SUB-SUBSECTION: Variant: Skills with Different Abilities
#     SUBSECTION: Passive Checks
#     SUBSECTION: Working Together
#       SUB-SUBSECTION: Group Checks
#   SECTION: Using Each Ability
#     SUBSECTION: Strength
#       SUB-SUBSECTION: Strength Checks
#       SUB-SUBSECTION: Attack Rolls and Damage
#       SUB-SUBSECTION: Lifting and Carrying
#       SUB-SUBSECTION: Variant: Encumbrance
#     SUBSECTION: Dexterity
#       SUB-SUBSECTION: Dexterity Checks
#       SUB-SUBSECTION: Attack Rolls and Damage
#       SUB-SUBSECTION: Armor Class
#       SUB-SUBSECTION: Initiative
#     SUBSECTION: Constitution
#       SUB-SUBSECTION: Constitution Checks
#       SUB-SUBSECTION: Hit Points
#     SUBSECTION: Intelligence
#       SUB-SUBSECTION: Intelligence Checks
#       SUB-SUBSECTION: Spellcasting Ability
#     SUBSECTION: Wisdom
#       SUB-SUBSECTION: Wisdom Checks
#       SUB-SUBSECTION: Spellcasting Ability
#     SUBSECTION: Charisma
#       SUB-SUBSECTION: Charisma Checks
#       SUB-SUBSECTION: Spellcasting Ability
#   SECTION: Saving Throws
#   SECTION: Time
#   SECTION: Movement
#     SUBSECTION: Speed
#       SUB-SUBSECTION: Travel Pace
#       SUB-SUBSECTION: Difficult Terrain
#     SUBSECTION: Special Types of Movement
#       SUB-SUBSECTION: Climbing, Swimming, and Crawling
#       SUB-SUBSECTION: Jumping
#   SECTION: The Environment
#     SUBSECTION: Falling
#     SUBSECTION: Suffocating
#     SUBSECTION: Vision and Light
#       SUB-SUBSECTION: Blindsight
#       SUB-SUBSECTION: Darkvision
#       SUB-SUBSECTION: Truesight
#     SUBSECTION: Food and Water
#       SUB-SUBSECTION: Food
#       SUB-SUBSECTION: Water
#     SUBSECTION: Interacting with Objects
#   SECTION: Resting
#     SUBSECTION: Short Rest
#     SUBSECTION: Long Rest
#   SECTION: Between Adventures
#     SUBSECTION: Lifestyle Expenses
#     SUBSECTION: Downtime Activities
#       SUB-SUBSECTION: Crafting
#       SUB-SUBSECTION: Practicing a Profession
#       SUB-SUBSECTION: Recuperating
#       SUB-SUBSECTION: Researching
#       SUB-SUBSECTION: Training
#   SECTION: The Order of Combat
#     SUBSECTION: Surprise
#     SUBSECTION: Initiative
#     SUBSECTION: Your Turn
#       SUB-SUBSECTION: Bonus Actions
#       SUB-SUBSECTION: Other Activity on Your Turn
#     SUBSECTION: Reactions
#   SECTION: Movement and Position
#     SUBSECTION: Breaking Up Your Move
#       SUB-SUBSECTION: Moving between Attacks
#       SUB-SUBSECTION: Using Different Speeds
#     SUBSECTION: Difficult Terrain
#     SUBSECTION: Being Prone
#     SUBSECTION: Moving Around Other Creatures
#     SUBSECTION: Flying Movement
#     SUBSECTION: Creature Size
#       SUB-SUBSECTION: Space
#       SUB-SUBSECTION: Squeezing into a Smaller Space
#   SECTION: Actions in Combat
#     SUBSECTION: Attack
#     SUBSECTION: Cast a Spell
#     SUBSECTION: Dash
#     SUBSECTION: Disengage
#     SUBSECTION: Dodge
#     SUBSECTION: Help
#     SUBSECTION: Hide
#     SUBSECTION: Ready
#     SUBSECTION: Search
#     SUBSECTION: Use an Object
#   SECTION: Making an Attack
#     SUBSECTION: Attack Rolls
#       SUB-SUBSECTION: Modifiers to the Roll
#       SUB-SUBSECTION: Rolling 1 or 20
#     SUBSECTION: Unseen Attackers and Targets
#     SUBSECTION: Ranged Attacks
#       SUB-SUBSECTION: Range
#       SUB-SUBSECTION: Ranged Attacks in Close Combat
#     SUBSECTION: Melee Attacks
#       SUB-SUBSECTION: Opportunity Attacks
#       SUB-SUBSECTION: Two-Weapon Fighting
#       SUB-SUBSECTION: Grappling
#       SUB-SUBSECTION: Shoving a Creature
#   SECTION: Cover
#   SECTION: Damage and Healing
#     SUBSECTION: Hit Points
#     SUBSECTION: Damage Rolls
#       SUB-SUBSECTION: Critical Hits
#       SUB-SUBSECTION: Damage Types
#     SUBSECTION: Damage Resistance and
#     SUBSECTION: Vulnerability
#     SUBSECTION: Healing
#     SUBSECTION: Dropping to 0 Hit Points
#       SUB-SUBSECTION: Instant Death
#       SUB-SUBSECTION: Falling Unconscious
#       SUB-SUBSECTION: Death Saving Throws
#       SUB-SUBSECTION: Stabilizing a Creature
#       SUB-SUBSECTION: Monsters and Death
#     SUBSECTION: Knocking a Creature Out
#     SUBSECTION: Temporary Hit Points
#   SECTION: Mounted Combat
#     SUBSECTION: Mounting and Dismounting
#     SUBSECTION: Controlling a Mount
#   SECTION: Underwater Combat
# CHAPTER: Spellcasting
#   SECTION: What Is a Spell?
#     SUBSECTION: Spell Level
#     SUBSECTION: Known and Prepared Spells
#     SUBSECTION: Spell Slots
#       SUB-SUBSECTION: Casting a Spell at a Higher Level
#     SUBSECTION: Cantrips
#     SUBSECTION: Rituals
#   SECTION: Casting a Spell
#     SUBSECTION: Casting Time
#       SUB-SUBSECTION: Bonus Action
#       SUB-SUBSECTION: Reactions
#       SUB-SUBSECTION: Longer Casting Times
#     SUBSECTION: Range
#     SUBSECTION: Components
#       SUB-SUBSECTION: Verbal (V)
#       SUB-SUBSECTION: Somatic (S)
#       SUB-SUBSECTION: Material (M)
#     SUBSECTION: Duration
#       SUB-SUBSECTION: Instantaneous
#       SUB-SUBSECTION: Concentration
#     SUBSECTION: Targets
#       SUB-SUBSECTION: A Clear Path to the Target
#       SUB-SUBSECTION: Targeting Yourself
#     SUBSECTION: Areas of Effect
#       SUB-SUBSECTION: Cone
#       SUB-SUBSECTION: Cube
#       SUB-SUBSECTION: Cylinder
#       SUB-SUBSECTION: Line
#       SUB-SUBSECTION: Sphere
#     SUBSECTION: Saving Throws
#     SUBSECTION: Attack Rolls
#     SUBSECTION: Combining Magical Effects
#   SECTION: Spell Lists
#     SUBSECTION: Bard Spells
#       SUB-SUBSECTION: Cantrips (0 Level)
#       SUB-SUBSECTION: 1st Level
#       SUB-SUBSECTION: 2nd Level
#       SUB-SUBSECTION: 3rd Level
#       SUB-SUBSECTION: 4th Level
#       SUB-SUBSECTION: 5th Level
#       SUB-SUBSECTION: 6th Level
#       SUB-SUBSECTION: 7th Level
#       SUB-SUBSECTION: 8th Level
#       SUB-SUBSECTION: 9th Level
#     SUBSECTION: Cleric Spells
#       SUB-SUBSECTION: Cantrips (0 Level)
#       SUB-SUBSECTION: 1st Level
#       SUB-SUBSECTION: 2nd Level
#       SUB-SUBSECTION: 3rd Level
#       SUB-SUBSECTION: 4th Level
#       SUB-SUBSECTION: 5th Level
#       SUB-SUBSECTION: 6th Level
#       SUB-SUBSECTION: 7th Level
#       SUB-SUBSECTION: 8th Level
#       SUB-SUBSECTION: 9th Level
#     SUBSECTION: Druid Spells
#       SUB-SUBSECTION: Cantrips (0 Level)
#       SUB-SUBSECTION: 1st Level
#       SUB-SUBSECTION: 2nd Level
#       SUB-SUBSECTION: 3rd Level
#       SUB-SUBSECTION: 4th Level
#       SUB-SUBSECTION: 5th Level
#       SUB-SUBSECTION: 6th Level
#       SUB-SUBSECTION: 7th Level
#       SUB-SUBSECTION: 8th Level
#       SUB-SUBSECTION: 9th Level
#     SUBSECTION: Paladin Spells
#       SUB-SUBSECTION: 1st Level
#       SUB-SUBSECTION: 2nd Level
#       SUB-SUBSECTION: 3rd Level
#       SUB-SUBSECTION: 4th Level
#       SUB-SUBSECTION: 5th Level
#     SUBSECTION: Ranger Spells
#       SUB-SUBSECTION: 1st Level
#       SUB-SUBSECTION: 2nd Level
#       SUB-SUBSECTION: 3rd Level
#       SUB-SUBSECTION: 4th Level
#       SUB-SUBSECTION: 5th Level
#     SUBSECTION: Sorcerer Spells
#       SUB-SUBSECTION: Cantrips (0 Level)
#       SUB-SUBSECTION: 1st Level
#       SUB-SUBSECTION: 2nd Level
#       SUB-SUBSECTION: 3rd Level
#       SUB-SUBSECTION: 4th Level
#       SUB-SUBSECTION: 5th Level
#       SUB-SUBSECTION: 6th Level
#       SUB-SUBSECTION: 7th Level
#       SUB-SUBSECTION: 8th Level
#       SUB-SUBSECTION: 9th Level
#     SUBSECTION: Warlock Spells
#       SUB-SUBSECTION: Cantrips (0 Level)
#       SUB-SUBSECTION: 1st Level
#       SUB-SUBSECTION: 2nd Level
#       SUB-SUBSECTION: 3rd Level
#       SUB-SUBSECTION: 4th Level
#       SUB-SUBSECTION: 5th Level
#       SUB-SUBSECTION: 6th Level
#       SUB-SUBSECTION: 7th Level
#       SUB-SUBSECTION: 8th Level
#       SUB-SUBSECTION: 9th Level
#     SUBSECTION: Wizard Spells
#       SUB-SUBSECTION: Cantrips (0 Level)
#       SUB-SUBSECTION: 1st Level
#       SUB-SUBSECTION: 2nd Level
#       SUB-SUBSECTION: 3rd Level
#       SUB-SUBSECTION: 4th Level
#       SUB-SUBSECTION: 5th Level
#       SUB-SUBSECTION: 6th Level
#       SUB-SUBSECTION: 7th Level
#       SUB-SUBSECTION: 8th Level
#       SUB-SUBSECTION: 9th Level
#   SECTION: Spell Descriptions
#       SUB-SUBSECTION: Acid Arrow
#       SUB-SUBSECTION: Acid Splash
#       SUB-SUBSECTION: Aid
#       SUB-SUBSECTION: Alarm
#       SUB-SUBSECTION: Alter Self
#       SUB-SUBSECTION: Animal Friendship
#       SUB-SUBSECTION: Animal Messenger
#       SUB-SUBSECTION: Animal Shapes
#       SUB-SUBSECTION: Animate Dead
#       SUB-SUBSECTION: Animate Objects
#       SUB-SUBSECTION: Antilife Shell
#       SUB-SUBSECTION: Antimagic Field
#       SUB-SUBSECTION: Antipathy/Sympathy
#       SUB-SUBSECTION: Arcane Eye
#       SUB-SUBSECTION: Arcane Hand
#       SUB-SUBSECTION: Arcane Lock
#       SUB-SUBSECTION: Arcane Sword
#       SUB-SUBSECTION: Arcanist’s Magic Aura
#       SUB-SUBSECTION: Astral Projection
#       SUB-SUBSECTION: Augury
#       SUB-SUBSECTION: Awaken
#       SUB-SUBSECTION: Bane
#       SUB-SUBSECTION: Banishment
#       SUB-SUBSECTION: Barkskin
#       SUB-SUBSECTION: Beacon of Hope
#       SUB-SUBSECTION: Bestow Curse
#       SUB-SUBSECTION: Black Tentacles
#       SUB-SUBSECTION: Blade Barrier
#       SUB-SUBSECTION: Bless
#       SUB-SUBSECTION: Blight
#       SUB-SUBSECTION: Blindness/Deafness
#       SUB-SUBSECTION: Blink
#       SUB-SUBSECTION: Blur
#       SUB-SUBSECTION: Branding Smite
#       SUB-SUBSECTION: Burning Hands
#       SUB-SUBSECTION: Call Lightning
#       SUB-SUBSECTION: Calm Emotions
#       SUB-SUBSECTION: Chain Lightning
#       SUB-SUBSECTION: Charm Person
#       SUB-SUBSECTION: Chill Touch
#       SUB-SUBSECTION: Circle of Death
#       SUB-SUBSECTION: Clairvoyance
#       SUB-SUBSECTION: Clone
#       SUB-SUBSECTION: Cloudkill
#       SUB-SUBSECTION: Color Spray
#       SUB-SUBSECTION: Command
#       SUB-SUBSECTION: Commune
#       SUB-SUBSECTION: Commune with Nature
#       SUB-SUBSECTION: Comprehend Languages
#       SUB-SUBSECTION: Compulsion
#       SUB-SUBSECTION: Cone of Cold
#       SUB-SUBSECTION: Confusion
#       SUB-SUBSECTION: Conjure Animals
#       SUB-SUBSECTION: Conjure Celestial
#       SUB-SUBSECTION: Conjure Elemental
#       SUB-SUBSECTION: Conjure Fey
#       SUB-SUBSECTION: Conjure Minor Elementals
#       SUB-SUBSECTION: Conjure Woodland Beings
#       SUB-SUBSECTION: Contact Other Plane
#       SUB-SUBSECTION: Contagion
#       SUB-SUBSECTION: Contingency
#       SUB-SUBSECTION: Continual Flame
#       SUB-SUBSECTION: Control Water
#       SUB-SUBSECTION: Control Weather
#       SUB-SUBSECTION: Counterspell
#       SUB-SUBSECTION: Create Food and Water
#       SUB-SUBSECTION: Create or Destroy Water
#       SUB-SUBSECTION: Create Undead
#       SUB-SUBSECTION: Creation
#       SUB-SUBSECTION: Cure Wounds
#       SUB-SUBSECTION: Dancing Lights
#       SUB-SUBSECTION: Darkness
#       SUB-SUBSECTION: Darkvision
#       SUB-SUBSECTION: Daylight
#       SUB-SUBSECTION: Death Ward
#       SUB-SUBSECTION: Delayed Blast Fireball
#       SUB-SUBSECTION: Demiplane
#       SUB-SUBSECTION: Detect Evil and Good
#       SUB-SUBSECTION: Detect Magic
#       SUB-SUBSECTION: Detect Poison and Disease
#       SUB-SUBSECTION: Detect Thoughts
#       SUB-SUBSECTION: Dimension Door
#       SUB-SUBSECTION: Disguise Self
#       SUB-SUBSECTION: Disintegrate
#       SUB-SUBSECTION: Dispel Evil and Good
#       SUB-SUBSECTION: Dispel Magic
#       SUB-SUBSECTION: Divination
#       SUB-SUBSECTION: Divine Favor
#       SUB-SUBSECTION: Divine Word
#       SUB-SUBSECTION: Dominate Beast
#       SUB-SUBSECTION: Dominate Monster
#       SUB-SUBSECTION: Dominate Person
#       SUB-SUBSECTION: Dream
#       SUB-SUBSECTION: Druidcraft
#       SUB-SUBSECTION: Earthquake
#       SUB-SUBSECTION: Eldritch Blast
#       SUB-SUBSECTION: Enhance Ability
#       SUB-SUBSECTION: Enlarge/Reduce
#       SUB-SUBSECTION: Entangle
#       SUB-SUBSECTION: Enthrall
#       SUB-SUBSECTION: Etherealness
#       SUB-SUBSECTION: Expeditious Retreat
#       SUB-SUBSECTION: Eyebite
#       SUB-SUBSECTION: Fabricate
#       SUB-SUBSECTION: Faerie Fire
#       SUB-SUBSECTION: Faithful Hound
#       SUB-SUBSECTION: False Life
#       SUB-SUBSECTION: Fear
#       SUB-SUBSECTION: Feather Fall
#       SUB-SUBSECTION: Feeblemind
#       SUB-SUBSECTION: Find Familiar
#       SUB-SUBSECTION: Find Steed
#       SUB-SUBSECTION: Find the Path
#       SUB-SUBSECTION: Find Traps
#       SUB-SUBSECTION: Finger of Death
#       SUB-SUBSECTION: Fireball
#       SUB-SUBSECTION: Fire Bolt
#       SUB-SUBSECTION: Fire Shield
#       SUB-SUBSECTION: Fire Storm
#       SUB-SUBSECTION: Flame Blade
#       SUB-SUBSECTION: Flame Strike
#       SUB-SUBSECTION: Flaming Sphere
#       SUB-SUBSECTION: Flesh to Stone
#       SUB-SUBSECTION: Floating Disk
#       SUB-SUBSECTION: Fly
#       SUB-SUBSECTION: Fog Cloud
#       SUB-SUBSECTION: Forbiddance
#       SUB-SUBSECTION: Forcecage
#       SUB-SUBSECTION: Foresight
#       SUB-SUBSECTION: Freedom of Movement
#       SUB-SUBSECTION: Freezing Sphere
#       SUB-SUBSECTION: Gaseous Form
#       SUB-SUBSECTION: Gate
#       SUB-SUBSECTION: Geas
#       SUB-SUBSECTION: Gentle Repose
#       SUB-SUBSECTION: Giant Insect
#       SUB-SUBSECTION: Glibness
#       SUB-SUBSECTION: Globe of Invulnerability
#       SUB-SUBSECTION: Glyph of Warding
#       SUB-SUBSECTION: Goodberry
#       SUB-SUBSECTION: Grease
#       SUB-SUBSECTION: Greater Invisibility
#       SUB-SUBSECTION: Greater Restoration
#       SUB-SUBSECTION: Guardian of Faith
#       SUB-SUBSECTION: Guards and Wards
#       SUB-SUBSECTION: Guidance
#       SUB-SUBSECTION: Guiding Bolt
#       SUB-SUBSECTION: Gust of Wind
#       SUB-SUBSECTION: Hallow
#       SUB-SUBSECTION: Hallucinatory Terrain
#       SUB-SUBSECTION: Harm
#       SUB-SUBSECTION: Haste
#       SUB-SUBSECTION: Heal
#       SUB-SUBSECTION: Healing Word
#       SUB-SUBSECTION: Heat Metal
#       SUB-SUBSECTION: Hellish Rebuke
#       SUB-SUBSECTION: Heroes’ Feast
#       SUB-SUBSECTION: Heroism
#       SUB-SUBSECTION: Hideous Laughter
#       SUB-SUBSECTION: Hold Monster
#       SUB-SUBSECTION: Hold Person
#       SUB-SUBSECTION: Holy Aura
#       SUB-SUBSECTION: Hunter’s Mark
#       SUB-SUBSECTION: Hypnotic Pattern
#       SUB-SUBSECTION: Ice Storm
#       SUB-SUBSECTION: Identify
#       SUB-SUBSECTION: Illusory Script
#       SUB-SUBSECTION: Imprisonment
#       SUB-SUBSECTION: Incendiary Cloud
#       SUB-SUBSECTION: Inflict Wounds
#       SUB-SUBSECTION: Insect Plague
#       SUB-SUBSECTION: Instant Summons
#       SUB-SUBSECTION: Invisibility
#       SUB-SUBSECTION: Irresistible Dance
#       SUB-SUBSECTION: Jump
#       SUB-SUBSECTION: Knock
#       SUB-SUBSECTION: Legend Lore
#       SUB-SUBSECTION: Lesser Restoration
#       SUB-SUBSECTION: Levitate
#       SUB-SUBSECTION: Light
#       SUB-SUBSECTION: Lightning Bolt
#       SUB-SUBSECTION: Locate Animals or Plants
#       SUB-SUBSECTION: Locate Creature
#       SUB-SUBSECTION: Locate Object
#       SUB-SUBSECTION: Longstrider
#       SUB-SUBSECTION: Mage Armor
#       SUB-SUBSECTION: Mage Hand
#       SUB-SUBSECTION: Magic Circle
#       SUB-SUBSECTION: Magic Jar
#       SUB-SUBSECTION: Magic Missile
#       SUB-SUBSECTION: Magic Mouth
#       SUB-SUBSECTION: Magic Weapon
#       SUB-SUBSECTION: Magnificent Mansion
#       SUB-SUBSECTION: Major Image
#       SUB-SUBSECTION: Mass Cure Wounds
#       SUB-SUBSECTION: Mass Heal
#       SUB-SUBSECTION: Mass Healing Word
#       SUB-SUBSECTION: Mass Suggestion
#       SUB-SUBSECTION: Maze
#       SUB-SUBSECTION: Meld into Stone
#       SUB-SUBSECTION: Mending
#       SUB-SUBSECTION: Message
#       SUB-SUBSECTION: Meteor Swarm
#       SUB-SUBSECTION: Mind Blank
#       SUB-SUBSECTION: Minor Illusion
#       SUB-SUBSECTION: Mirage Arcane
#       SUB-SUBSECTION: Mirror Image
#       SUB-SUBSECTION: Mislead
#       SUB-SUBSECTION: Misty Step
#       SUB-SUBSECTION: Modify Memory
#       SUB-SUBSECTION: Moonbeam
#       SUB-SUBSECTION: Move Earth
#       SUB-SUBSECTION: Nondetection
#       SUB-SUBSECTION: Pass without Trace
#       SUB-SUBSECTION: Passwall
#       SUB-SUBSECTION: Phantasmal Killer
#       SUB-SUBSECTION: Phantom Steed
#       SUB-SUBSECTION: Planar Ally
#       SUB-SUBSECTION: Planar Binding
#       SUB-SUBSECTION: Plane Shift
#       SUB-SUBSECTION: Plant Growth
#       SUB-SUBSECTION: Poison Spray
#       SUB-SUBSECTION: Polymorph
#       SUB-SUBSECTION: Power Word Kill
#       SUB-SUBSECTION: Power Word Stun
#       SUB-SUBSECTION: Prayer of Healing
#       SUB-SUBSECTION: Prestidigitation
#       SUB-SUBSECTION: Prismatic Spray
#       SUB-SUBSECTION: Prismatic Wall
#       SUB-SUBSECTION: Private Sanctum
#       SUB-SUBSECTION: Produce Flame
#       SUB-SUBSECTION: Programmed Illusion
#       SUB-SUBSECTION: Project Image
#       SUB-SUBSECTION: Protection from Energy
#       SUB-SUBSECTION: Protection from Evil and Good
#       SUB-SUBSECTION: Protection from Poison
#       SUB-SUBSECTION: Purify Food and Drink
#       SUB-SUBSECTION: Raise Dead
#       SUB-SUBSECTION: Ray of Enfeeblement
#       SUB-SUBSECTION: Ray of Frost
#       SUB-SUBSECTION: Regenerate
#       SUB-SUBSECTION: Reincarnate
#       SUB-SUBSECTION: Remove Curse
#       SUB-SUBSECTION: Resilient Sphere
#       SUB-SUBSECTION: Resistance
#       SUB-SUBSECTION: Resurrection
#       SUB-SUBSECTION: Reverse Gravity
#       SUB-SUBSECTION: Revivify
#       SUB-SUBSECTION: Rope Trick
#       SUB-SUBSECTION: Sacred Flame
#       SUB-SUBSECTION: Sanctuary
#       SUB-SUBSECTION: Scorching Ray
#       SUB-SUBSECTION: Scrying
#       SUB-SUBSECTION: Secret Chest
#       SUB-SUBSECTION: See Invisibility
#       SUB-SUBSECTION: Seeming
#       SUB-SUBSECTION: Sending
#       SUB-SUBSECTION: Sequester
#       SUB-SUBSECTION: Shapechange
#       SUB-SUBSECTION: Shatter
#       SUB-SUBSECTION: Shield
#       SUB-SUBSECTION: Shield of Faith
#       SUB-SUBSECTION: Shillelagh
#       SUB-SUBSECTION: Shocking Grasp
#       SUB-SUBSECTION: Silence
#       SUB-SUBSECTION: Silent Image
#       SUB-SUBSECTION: Simulacrum
#       SUB-SUBSECTION: Sleep
#       SUB-SUBSECTION: Sleet Storm
#       SUB-SUBSECTION: Slow
#       SUB-SUBSECTION: Spare the Dying
#       SUB-SUBSECTION: Speak with Animals
#       SUB-SUBSECTION: Speak with Dead
#       SUB-SUBSECTION: Speak with Plants
#       SUB-SUBSECTION: Spider Climb
#       SUB-SUBSECTION: Spike Growth
#       SUB-SUBSECTION: Spirit Guardians
#       SUB-SUBSECTION: Spiritual Weapon
#       SUB-SUBSECTION: Stinking Cloud
#       SUB-SUBSECTION: Stone Shape
#       SUB-SUBSECTION: Stoneskin
#       SUB-SUBSECTION: Storm of Vengeance
#       SUB-SUBSECTION: Suggestion
#       SUB-SUBSECTION: Sunbeam
#       SUB-SUBSECTION: Sunburst
#       SUB-SUBSECTION: Symbol
#       SUB-SUBSECTION: Telekinesis
#       SUB-SUBSECTION: Telepathic Bond
#       SUB-SUBSECTION: Teleport
#       SUB-SUBSECTION: Teleportation Circle
#       SUB-SUBSECTION: Thaumaturgy
#       SUB-SUBSECTION: Thunderwave
#       SUB-SUBSECTION: Time Stop
#       SUB-SUBSECTION: Tiny Hut
#       SUB-SUBSECTION: Tongues
#       SUB-SUBSECTION: Transport via Plants
#       SUB-SUBSECTION: Tree Stride
#       SUB-SUBSECTION: True Polymorph
#       SUB-SUBSECTION: True Resurrection
#       SUB-SUBSECTION: True Seeing
#       SUB-SUBSECTION: True Strike
#       SUB-SUBSECTION: Unseen Servant
#       SUB-SUBSECTION: Vampiric Touch
#       SUB-SUBSECTION: Vicious Mockery
#       SUB-SUBSECTION: Wall of Fire
#       SUB-SUBSECTION: Wall of Force
#       SUB-SUBSECTION: Wall of Ice
#       SUB-SUBSECTION: Wall of Stone
#       SUB-SUBSECTION: Wall of Thorns
#       SUB-SUBSECTION: Warding Bond
#       SUB-SUBSECTION: Water Breathing
#       SUB-SUBSECTION: Water Walk
#       SUB-SUBSECTION: Web
#       SUB-SUBSECTION: Weird
#       SUB-SUBSECTION: Wind Walk
#       SUB-SUBSECTION: Wind Wall
#       SUB-SUBSECTION: Wish
#       SUB-SUBSECTION: Word of Recall
#       SUB-SUBSECTION: Zone of Truth
#   SECTION: Traps
#     SUBSECTION: Traps in Play
#       SUB-SUBSECTION: Triggering a Trap
#       SUB-SUBSECTION: Detecting and Disabling a Trap
#       SUB-SUBSECTION: Trap Effects
#       SUB-SUBSECTION: Complex Traps
#     SUBSECTION: Sample Traps
#       SUB-SUBSECTION: Collapsing Roof
#       SUB-SUBSECTION: Falling Net
#       SUB-SUBSECTION: Fire-Breathing Statue
#       SUB-SUBSECTION: Pits
#       SUB-SUBSECTION: Poison Darts
#       SUB-SUBSECTION: Poison Needle
#       SUB-SUBSECTION: Rolling Sphere
#       SUB-SUBSECTION: Sphere of Annihilation
#   SECTION: Diseases
#     SUBSECTION: Sample Diseases
#       SUB-SUBSECTION: Cackle Fever
#       SUB-SUBSECTION: Sewer Plague
#       SUB-SUBSECTION: Sight Rot
#   SECTION: Madness
#     SUBSECTION: Going Mad
#     SUBSECTION: Madness Effects
#     SUBSECTION: Curing Madness
#   SECTION: Objects
#       SUB-SUBSECTION: Statistics for Objects
#   SECTION: Poisons
#     SUBSECTION: Sample Poisons
# CHAPTER: Magic Items
#   SECTION: Attunement
#   SECTION: Wearing and Wielding Items
#     SUBSECTION: Multiple Items of the Same Kind
#     SUBSECTION: Paired Items
#   SECTION: Activating an Item
#     SUBSECTION: Command Word
#     SUBSECTION: Consumables
#     SUBSECTION: Spells
#     SUBSECTION: Charges
#   SECTION: Magic Items A-Z
#       SUB-SUBSECTION: Adamantine Armor
#       SUB-SUBSECTION: Ammunition, +1, +2, or +3
#       SUB-SUBSECTION: Amulet of Health
#       SUB-SUBSECTION: Amulet of Proof against Detection and
#       SUB-SUBSECTION: Location
#       SUB-SUBSECTION: Amulet of the Planes
#       SUB-SUBSECTION: Animated Shield
#       SUB-SUBSECTION: Apparatus of the Crab
#       SUB-SUBSECTION: Armor, +1, +2, or +3
#       SUB-SUBSECTION: Armor of Invulnerability
#       SUB-SUBSECTION: Armor of Resistance
#       SUB-SUBSECTION: Armor of Vulnerability
#       SUB-SUBSECTION: Arrow-Catching Shield
#       SUB-SUBSECTION: Arrow of Slaying
#       SUB-SUBSECTION: Bag of Beans
#       SUB-SUBSECTION: Bag of Devouring
#       SUB-SUBSECTION: Bag of Holding
#       SUB-SUBSECTION: Bag of Tricks
#       SUB-SUBSECTION: Bead of Force
#       SUB-SUBSECTION: Belt of Dwarvenkind
#       SUB-SUBSECTION: Belt of Giant Strength
#       SUB-SUBSECTION: Berserker Axe
#       SUB-SUBSECTION: Boots of Elvenkind
#       SUB-SUBSECTION: Boots of Levitation
#       SUB-SUBSECTION: Boots of Speed
#       SUB-SUBSECTION: Boots of Striding and Springing
#       SUB-SUBSECTION: Boots of the Winterlands
#       SUB-SUBSECTION: Bowl of Commanding Water Elementals
#       SUB-SUBSECTION: Bracers of Archery
#       SUB-SUBSECTION: Bracers of Defense
#       SUB-SUBSECTION: Brazier of Commanding Fire Elementals
#       SUB-SUBSECTION: Brooch of Shielding
#       SUB-SUBSECTION: Broom of Flying
#       SUB-SUBSECTION: Candle of Invocation
#       SUB-SUBSECTION: Cape of the Mountebank
#       SUB-SUBSECTION: Carpet of Flying
#       SUB-SUBSECTION: Censer of Controlling Air Elementals
#       SUB-SUBSECTION: Chime of Opening
#       SUB-SUBSECTION: Circlet of Blasting
#       SUB-SUBSECTION: Cloak of Arachnida
#       SUB-SUBSECTION: Cloak of Displacement
#       SUB-SUBSECTION: Cloak of Elvenkind
#       SUB-SUBSECTION: Cloak of Protection
#       SUB-SUBSECTION: Cloak of the Bat
#       SUB-SUBSECTION: Cloak of the Manta Ray
#       SUB-SUBSECTION: Crystal Ball
#       SUB-SUBSECTION: Cube of Force
#       SUB-SUBSECTION: Cubic Gate
#       SUB-SUBSECTION: Dagger of Venom
#       SUB-SUBSECTION: Dancing Sword
#       SUB-SUBSECTION: Decanter of Endless Water
#       SUB-SUBSECTION: Deck of Illusions
#       SUB-SUBSECTION: Deck of Many Things
#       SUB-SUBSECTION: Defender
#       SUB-SUBSECTION: Demon Armor
#       SUB-SUBSECTION: Dimensional Shackles
#       SUB-SUBSECTION: Dragon Scale Mail
#       SUB-SUBSECTION: Dragon Slayer
#       SUB-SUBSECTION: Dust of Disappearance
#       SUB-SUBSECTION: Dust of Dryness
#       SUB-SUBSECTION: Dust of Sneezing and Choking
#       SUB-SUBSECTION: Dwarven Plate
#       SUB-SUBSECTION: Dwarven Thrower
#       SUB-SUBSECTION: Efficient Quiver
#       SUB-SUBSECTION: Efreeti Bottle
#       SUB-SUBSECTION: Elemental Gem
#       SUB-SUBSECTION: Elven Chain
#       SUB-SUBSECTION: Eversmoking Bottle
#       SUB-SUBSECTION: Eyes of Charming
#       SUB-SUBSECTION: Eyes of Minute Seeing
#       SUB-SUBSECTION: Eyes of the Eagle
#       SUB-SUBSECTION: Feather Token
#       SUB-SUBSECTION: Figurine of Wondrous Power
#       SUB-SUBSECTION: Flame Tongue
#       SUB-SUBSECTION: Folding Boat
#       SUB-SUBSECTION: Frost Brand
#       SUB-SUBSECTION: Gauntlets of Ogre Power
#       SUB-SUBSECTION: Gem of Brightness
#       SUB-SUBSECTION: Gem of Seeing
#       SUB-SUBSECTION: Giant Slayer
#       SUB-SUBSECTION: Glamoured Studded Leather
#       SUB-SUBSECTION: Gloves of Missile Snaring
#       SUB-SUBSECTION: Gloves of Swimming and Climbing
#       SUB-SUBSECTION: Goggles of Night
#       SUB-SUBSECTION: Hammer of Thunderbolts
#       SUB-SUBSECTION: Handy Haversack
#       SUB-SUBSECTION: Hat of Disguise
#       SUB-SUBSECTION: Headband of Intellect
#       SUB-SUBSECTION: Helm of Brilliance
#       SUB-SUBSECTION: Helm of Comprehending Languages
#       SUB-SUBSECTION: Helm of Telepathy
#       SUB-SUBSECTION: Helm of Teleportation
#       SUB-SUBSECTION: Holy Avenger
#       SUB-SUBSECTION: Horn of Blasting
#       SUB-SUBSECTION: Horn of Valhalla
#       SUB-SUBSECTION: Horseshoes of a Zephyr
#       SUB-SUBSECTION: Horseshoes of Speed
#       SUB-SUBSECTION: Immovable Rod
#       SUB-SUBSECTION: Instant Fortress
#       SUB-SUBSECTION: Ioun Stone
#       SUB-SUBSECTION: Iron Bands of Binding
#       SUB-SUBSECTION: Iron Flask
#       SUB-SUBSECTION: Javelin of Lightning
#       SUB-SUBSECTION: Lantern of Revealing
#       SUB-SUBSECTION: Luck Blade
#       SUB-SUBSECTION: Mace of Disruption
#       SUB-SUBSECTION: Mace of Smiting
#       SUB-SUBSECTION: Mace of Terror
#       SUB-SUBSECTION: Mantle of Spell Resistance
#       SUB-SUBSECTION: Manual of Bodily Health
#       SUB-SUBSECTION: Manual of Gainful Exercise
#       SUB-SUBSECTION: Manual of Golems
#       SUB-SUBSECTION: Manual of Quickness of Action
#       SUB-SUBSECTION: Marvelous Pigments
#       SUB-SUBSECTION: Medallion of Thoughts
#       SUB-SUBSECTION: Mirror of Life Trapping
#       SUB-SUBSECTION: Mithral Armor
#       SUB-SUBSECTION: Necklace of Adaptation
#       SUB-SUBSECTION: Necklace of Fireballs
#       SUB-SUBSECTION: Necklace of Prayer Beads
#       SUB-SUBSECTION: Nine Lives Stealer
#       SUB-SUBSECTION: Oathbow
#       SUB-SUBSECTION: Oil of Etherealness
#       SUB-SUBSECTION: Oil of Sharpness
#       SUB-SUBSECTION: Oil of Slipperiness
#       SUB-SUBSECTION: Pearl of Power
#       SUB-SUBSECTION: Periapt of Health
#       SUB-SUBSECTION: Periapt of Proof against Poison
#       SUB-SUBSECTION: Periapt of Wound Closure
#       SUB-SUBSECTION: Philter of Love
#       SUB-SUBSECTION: Pipes of Haunting
#       SUB-SUBSECTION: Pipes of the Sewers
#       SUB-SUBSECTION: Plate Armor of Etherealness
#       SUB-SUBSECTION: Portable Hole
#       SUB-SUBSECTION: Potion of Animal Friendship
#       SUB-SUBSECTION: Potion of Clairvoyance
#       SUB-SUBSECTION: Potion of Climbing
#       SUB-SUBSECTION: Potion of Diminution
#       SUB-SUBSECTION: Potion of Flying
#       SUB-SUBSECTION: Potion of Gaseous Form
#       SUB-SUBSECTION: Potion of Giant Strength
#       SUB-SUBSECTION: Potion of Growth
#       SUB-SUBSECTION: Potion of Healing
#       SUB-SUBSECTION: Potion of Heroism
#       SUB-SUBSECTION: Potion of Invisibility
#       SUB-SUBSECTION: Potion of Mind Reading
#       SUB-SUBSECTION: Potion of Poison
#       SUB-SUBSECTION: Potion of Resistance
#       SUB-SUBSECTION: Potion of Speed
#       SUB-SUBSECTION: Potion of Water Breathing
#       SUB-SUBSECTION: Restorative Ointment
#       SUB-SUBSECTION: Ring of Animal Influence
#       SUB-SUBSECTION: Ring of Djinni Summoning
#       SUB-SUBSECTION: Ring of Elemental Command
#       SUB-SUBSECTION: Ring of Evasion
#       SUB-SUBSECTION: Ring of Feather Falling
#       SUB-SUBSECTION: Ring of Free Action
#       SUB-SUBSECTION: Ring of Invisibility
#       SUB-SUBSECTION: Ring of Jumping
#       SUB-SUBSECTION: Ring of Mind Shielding
#       SUB-SUBSECTION: Ring of Protection
#       SUB-SUBSECTION: Ring of Regeneration
#       SUB-SUBSECTION: Ring of Resistance
#       SUB-SUBSECTION: Ring of Shooting Stars
#       SUB-SUBSECTION: Ring of Spell Storing
#       SUB-SUBSECTION: Ring of Spell Turning
#       SUB-SUBSECTION: Ring of Swimming
#       SUB-SUBSECTION: Ring of Telekinesis
#       SUB-SUBSECTION: Ring of the Ram
#       SUB-SUBSECTION: Ring of Three Wishes
#       SUB-SUBSECTION: Ring of Warmth
#       SUB-SUBSECTION: Ring of Water Walking
#       SUB-SUBSECTION: Ring of X-ray Vision
#       SUB-SUBSECTION: Robe of Eyes
#       SUB-SUBSECTION: Robe of Scintillating Colors
#       SUB-SUBSECTION: Robe of Stars
#       SUB-SUBSECTION: Robe of the Archmagi
#       SUB-SUBSECTION: Robe of Useful Items
#       SUB-SUBSECTION: Rod of Absorption
#       SUB-SUBSECTION: Rod of Alertness
#       SUB-SUBSECTION: Rod of Lordly Might
#       SUB-SUBSECTION: Rod of Rulership
#       SUB-SUBSECTION: Rod of Security
#       SUB-SUBSECTION: Rope of Climbing
#       SUB-SUBSECTION: Rope of Entanglement
#       SUB-SUBSECTION: Scarab of Protection
#       SUB-SUBSECTION: Scimitar of Speed
#       SUB-SUBSECTION: Shield, +1, +2, or +3
#       SUB-SUBSECTION: Shield of Missile Attraction
#       SUB-SUBSECTION: Slippers of Spider Climbing
#       SUB-SUBSECTION: Sovereign Glue
#       SUB-SUBSECTION: Spell Scroll
#       SUB-SUBSECTION: Spellguard Shield
#       SUB-SUBSECTION: Sphere of Annihilation
#       SUB-SUBSECTION: Staff of Charming
#       SUB-SUBSECTION: Staff of Fire
#       SUB-SUBSECTION: Staff of Frost
#       SUB-SUBSECTION: Staff of Healing
#       SUB-SUBSECTION: Staff of Power
#       SUB-SUBSECTION: Staff of Striking
#       SUB-SUBSECTION: Staff of Swarming Insects
#       SUB-SUBSECTION: Staff of the Magi
#       SUB-SUBSECTION: Staff of the Python
#       SUB-SUBSECTION: Staff of the Woodlands
#       SUB-SUBSECTION: Staff of Thunder and Lightning
#       SUB-SUBSECTION: Staff of Withering
#       SUB-SUBSECTION: Stone of Controlling Earth Elementals
#       SUB-SUBSECTION: Stone of Good Luck (Luckstone)
#       SUB-SUBSECTION: Sun Blade
#       SUB-SUBSECTION: Sword of Life Stealing
#       SUB-SUBSECTION: Sword of Sharpness
#       SUB-SUBSECTION: Sword of Wounding
#       SUB-SUBSECTION: Talisman of Pure Good
#       SUB-SUBSECTION: Talisman of the Sphere
#       SUB-SUBSECTION: Talisman of Ultimate Evil
#       SUB-SUBSECTION: Tome of Clear Thought
#       SUB-SUBSECTION: Tome of Leadership and Influence
#       SUB-SUBSECTION: Tome of Understanding
#       SUB-SUBSECTION: Trident of Fish Command
#       SUB-SUBSECTION: Universal Solvent
#       SUB-SUBSECTION: Vicious Weapon
#       SUB-SUBSECTION: Vorpal Sword
#       SUB-SUBSECTION: Wand of Binding
#       SUB-SUBSECTION: Wand of Enemy Detection
#       SUB-SUBSECTION: Wand of Fear
#       SUB-SUBSECTION: Wand of Fireballs
#       SUB-SUBSECTION: Wand of Lightning Bolts
#       SUB-SUBSECTION: Wand of Magic Detection
#       SUB-SUBSECTION: Wand of Magic Missiles
#       SUB-SUBSECTION: Wand of Paralysis
#       SUB-SUBSECTION: Wand of Polymorph
#       SUB-SUBSECTION: Wand of Secrets
#       SUB-SUBSECTION: Wand of the War Mage, +1, +2, or +3
#       SUB-SUBSECTION: Wand of Web
#       SUB-SUBSECTION: Wand of Wonder
#       SUB-SUBSECTION: Weapon, +1, +2, or +3
#       SUB-SUBSECTION: Well of Many Worlds
#       SUB-SUBSECTION: Wind Fan
#       SUB-SUBSECTION: Winged Boots
#       SUB-SUBSECTION: Wings of Flying
#   SECTION: Sentient Magic Items
#     SUBSECTION: Creating Sentient Magic Items
#       SUB-SUBSECTION: Abilities
#       SUB-SUBSECTION: Communication
#       SUB-SUBSECTION: Senses
#       SUB-SUBSECTION: Alignment
#       SUB-SUBSECTION: Special Purpose
#     SUBSECTION: Conflict
#   SECTION: Artifacts
#       SUB-SUBSECTION: Orb of Dragonkind
# CHAPTER: Monsters
#     SUBSECTION: Size
#     SUBSECTION: Type
#       SUB-SUBSECTION: Tags
#     SUBSECTION: Alignment
#     SUBSECTION: Armor Class
#     SUBSECTION: Hit Points
#     SUBSECTION: Speed
#       SUB-SUBSECTION: Burrow
#       SUB-SUBSECTION: Climb
#       SUB-SUBSECTION: Fly
#       SUB-SUBSECTION: Swim
#     SUBSECTION: Ability Scores
#     SUBSECTION: Saving Throws
#     SUBSECTION: Skills
#     SUBSECTION: Vulnerabilities, Resistances, and
#     SUBSECTION: Immunities
#     SUBSECTION: Senses
#       SUB-SUBSECTION: Blindsight
#       SUB-SUBSECTION: Darkvision
#       SUB-SUBSECTION: Tremorsense
#       SUB-SUBSECTION: Truesight
#     SUBSECTION: Languages
#       SUB-SUBSECTION: Telepathy
#     SUBSECTION: Challenge
#       SUB-SUBSECTION: Experience Points
#     SUBSECTION: Special Traits
#       SUB-SUBSECTION: Innate Spellcasting
#       SUB-SUBSECTION: Spellcasting
#       SUB-SUBSECTION: Psionics
#     SUBSECTION: Actions
#       SUB-SUBSECTION: Melee and Ranged Attacks
#       SUB-SUBSECTION: Multiattack
#       SUB-SUBSECTION: Ammunition
#     SUBSECTION: Reactions
#     SUBSECTION: Limited Usage
#     SUBSECTION: Equipment
#   SECTION: Legendary Creatures
#     SUBSECTION: Legendary Actions
#     SUBSECTION: A Legendary Creature’s Lair
#       SUB-SUBSECTION: Lair Actions
#       SUB-SUBSECTION: Regional Effects
#   SECTION: Monsters (A)
#     SUBSECTION: Angels
#     SUBSECTION: Animated Objects
#   SECTION: Monsters (B)
#   SECTION: Monsters (C)
#   SECTION: Monsters (D)
#     SUBSECTION: Demons
#     SUBSECTION: Devils
#     SUBSECTION: Dinosaurs
#     SUBSECTION: Dragons, Chromatic
#       SUB-SUBSECTION: Black Dragon
#       SUB-SUBSECTION: Blue Dragon
#       SUB-SUBSECTION: Green Dragon
#       SUB-SUBSECTION: Red Dragon
#       SUB-SUBSECTION: White Dragon
#     SUBSECTION: Dragons, Metallic
#       SUB-SUBSECTION: Brass Dragon
#       SUB-SUBSECTION: Bronze Dragon
#       SUB-SUBSECTION: Copper Dragon
#       SUB-SUBSECTION: Gold Dragon
#       SUB-SUBSECTION: Silver Dragon
#   SECTION: Monsters (E)
#     SUBSECTION: Elementals
#   SECTION: Monsters (F)
#     SUBSECTION: Fungi
#   SECTION: Monsters (G)
#     SUBSECTION: Genies
#     SUBSECTION: Ghouls
#     SUBSECTION: Giants
#     SUBSECTION: Golems
#   SECTION: Monsters (H)
#     SUBSECTION: Hags
#     SUBSECTION: Half-Dragon Template
#   SECTION: Monsters (I)
#   SECTION: Monsters (K)
#   SECTION: Monsters (L)
#     SUBSECTION: Lycanthropes
#   SECTION: Monsters (M)
#     SUBSECTION: Mephits
#     SUBSECTION: Mummies
#   SECTION: Monsters (N)
#     SUBSECTION: Nagas
#   SECTION: Monsters (O)
#     SUBSECTION: Oozes
#   SECTION: Monsters (P)
#   SECTION: Monsters (R)
#   SECTION: Monsters (S)
#     SUBSECTION: Skeletons
#     SUBSECTION: Sphinxes
#   SECTION: Monsters (T)
#   SECTION: Monsters (U)
#   SECTION: Monsters (V)
#     SUBSECTION: Vampires
#   SECTION: Monsters (W)
#   SECTION: Monsters (X)
#   SECTION: Monsters (Z)
#     SUBSECTION: Zombies
# CHAPTER: Appendix PH-A:
# CHAPTER: Conditions
#       SUB-SUBSECTION: Blinded
#       SUB-SUBSECTION: Charmed
#       SUB-SUBSECTION: Deafened
#       SUB-SUBSECTION: Frightened
#       SUB-SUBSECTION: Grappled
#       SUB-SUBSECTION: Incapacitated
#       SUB-SUBSECTION: Invisible
#       SUB-SUBSECTION: Paralyzed
#       SUB-SUBSECTION: Petrified
#       SUB-SUBSECTION: Poisoned
#       SUB-SUBSECTION: Prone
#       SUB-SUBSECTION: Restrained
#       SUB-SUBSECTION: Stunned
#       SUB-SUBSECTION: Unconscious
# CHAPTER: Appendix PH-B:
# CHAPTER: Fantasy-Historical
# CHAPTER: Pantheons
#       SUB-SUBSECTION: The Celtic Pantheon
#       SUB-SUBSECTION: The Greek Pantheon
#       SUB-SUBSECTION: The Egyptian Pantheon
#       SUB-SUBSECTION: The Norse Pantheon
# CHAPTER: Appendix PH-C:
# CHAPTER: The Planes of
# CHAPTER: Existence
#   SECTION: The Material Plane
#   SECTION: Beyond the Material
#     SUBSECTION: Planar Travel
#     SUBSECTION: Transitive Planes
#     SUBSECTION: Inner Planes
#     SUBSECTION: Outer Planes
#       SUB-SUBSECTION: Outer Planes
#       SUB-SUBSECTION: Demiplanes
# CHAPTER: Appendix MM-A:
# CHAPTER: Miscellaneous
# CHAPTER: Creatures
# CHAPTER: Appendix MM-B:
# CHAPTER: Nonplayer
# CHAPTER: Characters
#     SUBSECTION: Customizing NPCs

# %%
import re

def clean_text_lines(text: str) -> str:
    text = text.replace('\t\r \xa0', ' ')
    text = text.replace('\n', ' ')
    text = text.replace('\xa0', ' ')
    text = text.replace('-\xad‐‑', '-')
    text = strip_boilerplate(text)
    return text

# %%
# looks good, so let's record wayfinding and make document chunks
def is_heading_block(line, heading_traits) -> bool:
    if line['font'] == heading_traits['font'] and line['size'] == heading_traits['size'] and line['color'] == heading_traits['color']:
        return True
    return False

wayfinding = { 'chapter': 'Legal Information', 'section': None, 'subsection': None, 'subsubsection': None, 'starting_page': None}
chunk_content = ""
doc_chunks = []

for i, page in enumerate(doc):
    page_num = i+1

    d = page.get_text('dict')
    blocks = d['blocks']
    for block in blocks:
        if "lines" in block.keys():
            spans = block['lines']
            for span in spans:
                data = span['spans']
                for lines in data:
                    found_heading = False
                    trimmed_text = clean_text_lines(lines['text'].strip())
                    # clone last heading
                    last_heading = wayfinding.copy()

                    # each new heading resets the wayfinding for the lower levels
                    if is_heading_block(lines, CHAPTER):
                        wayfinding['chapter'] = trimmed_text
                        wayfinding['section'] = None
                        wayfinding['subsection'] = None
                        wayfinding['subsubsection'] = None
                        found_heading = True

                    if is_heading_block(lines, SECTION):
                        wayfinding['section'] = trimmed_text
                        wayfinding['subsection'] = None
                        wayfinding['subsubsection'] = None
                        found_heading = True

                    if is_heading_block(lines, SUBSECTION):
                        wayfinding['subsection'] = trimmed_text
                        wayfinding['subsubsection'] = None
                        found_heading = True

                    if is_heading_block(lines, SUBSUBSECTION):
                        wayfinding['subsubsection'] = trimmed_text
                        found_heading = True

                    if not found_heading:
                        chunk_content += trimmed_text + " "
                    else:
                        # end the content of the previous chunk, if there was any
                        if chunk_content != "":
                            previous_chunk = {
                                'location': last_heading,
                                'content': chunk_content
                            }
                            doc_chunks.append(previous_chunk)
                        chunk_content = ""
                        wayfinding['starting_page'] = page_num

# finish the last chunk
previous_chunk = {
    'location': wayfinding,
    'content': chunk_content
}
doc_chunks.append(previous_chunk)

print(len(doc_chunks))
pprint(doc_chunks[100])
# Out:
# 1392
# {'content': 'Drawing on the divine essence of nature itself, you can cast '
#             'spells to shape that essence to your will. System Reference '
#             'Document 5.1 20  ',
#  'location': {'chapter': 'Druid',
#               'section': 'Class Features',
#               'starting_page': 19,
#               'subsection': 'Spellcasting',
#               'subsubsection': None}}

# %%
# show 5 randomly selected chunks
import random
for i in range(5):
    chunk_index = random.randint(0, len(doc_chunks))
    pprint(doc_chunks[chunk_index])
# Out:
# {'content': 'Weapon (any sword), legendary (requires attunement) You gain a +3 '
#             'bonus to attack and damage rolls made with this magic weapon. The '
#             'first time you attack with the sword on each of your turns, you '
#             'can transfer some or all of the sword’s bonus to your Armor '
#             'Class, instead of using the bonus on any attacks that turn. For '
#             'example, you could reduce the bonus to your attack and damage '
#             'rolls to +1 and gain a +2 bonus to AC. The adjusted bonuses '
#             'remain in effect until the start of your next turn, although you '
#             'must hold the sword to gain a bonus to AC from it. ',
#  'location': {'chapter': 'Magic Items',
#               'section': 'Magic Items A-Z',
#               'starting_page': 218,
#               'subsection': None,
#               'subsubsection': 'Defender'}}
# {'content': 'Wondrous item, rarity varies (requires attunement) An Ioun stone '
#             'is named after Ioun, a god of knowledge and prophecy revered on '
#             'some worlds. Many types of Ioun stone exist, each type a distinct '
#             'combination of shape and color. When you use an action to toss '
#             'one of these stones into the air, the stone orbits your head at a '
#             'distance of 1d3 feet and confers a benefit to you. Thereafter, '
#             'another creature must use an action to grasp or net the stone to '
#             'separate it from you, either by making a successful attack roll '
#             'against AC 24 or a successful DC 24 Dexterity (Acrobatics) check. '
#             'You can use an action to seize and stow the stone, ending its '
#             'effect. A stone has AC 24, 10 hit points, and resistance to all '
#             'damage. It is considered to be an object that is being worn while '
#             'it orbits your head.  Absorption (Very Rare). While this pale '
#             'lavender ellipsoid orbits your head, you can use your reaction to '
#             'cancel a spell of 4th level or lower cast by a creature you can '
#             'see and targeting only you. Once the stone has canceled 20 levels '
#             'of spells, it burns out and turns dull gray, losing its magic. If '
#             'you are targeted by a spell whose level is higher than the number '
#             'of spell levels the stone has left, the stone can’t cancel it.  '
#             'Agility (Very Rare). Your Dexterity score increases by 2, to a '
#             'maximum of 20, while this deep red sphere orbits your head.  '
#             'Awareness (Rare). You can’t be surprised while this dark blue '
#             'rhomboid orbits your head.  Fortitude (Very Rare). Your '
#             'Constitution score increases by 2, to a maximum of 20, while this '
#             'pink rhomboid orbits your head.  Greater Absorption (Legendary). '
#             'While this marbled lavender and green ellipsoid orbits your head, '
#             'you can use your reaction to cancel a spell of 8th level or lower '
#             'cast by a creature you can see and targeting only you. Once the '
#             'stone has canceled 50 levels of spells, it burns out and turns '
#             'dull gray, losing its magic. If you are targeted by a spell whose '
#             'level is higher than the number of spell levels the stone has '
#             'left, the stone can’t cancel it.  Insight (Very Rare). Your '
#             'Wisdom score increases by 2, to a maximum of 20, while this '
#             'incandescent blue sphere orbits your head.  Intellect (Very '
#             'Rare). Your Intelligence score increases by 2, to a maximum of '
#             '20, while this marbled scarlet and blue sphere orbits your head.  '
#             'Leadership (Very Rare). Your Charisma score increases by 2, to a '
#             'maximum of 20, while this marbled pink and green sphere orbits '
#             'your head.  Mastery (Legendary). Your proficiency bonus increases '
#             'by 1 while this pale green prism orbits your head.  Protection '
#             '(Rare). You gain a +1 bonus to AC while this dusty rose prism '
#             'orbits your head.  Regeneration (Legendary). You regain 15 hit '
#             'points at the end of each hour this pearly white spindle orbits '
#             'your head, provided that you have at least 1 hit point.  Reserve '
#             '(Rare). This vibrant purple prism stores spells cast into it, '
#             'holding them until you use them. The stone can store up to 3 '
#             'levels worth of spells at a time. When found, it contains 1d4 − 1 '
#             'levels of stored spells chosen by the GM. Any creature can cast a '
#             'spell of 1st through 3rd level into the stone by touching it as '
#             'the spell is cast. The spell has no effect, other than to be '
#             'stored in the stone. If the stone can’t hold the spell, the spell '
#             'is expended without effect. The level of the slot used to cast '
#             'the spell determines how much space it uses. While this stone '
#             'orbits your head, you can cast any spell stored in it. The spell '
#             'uses the slot level, spell save DC, spell attack bonus, and '
#             'spellcasting ability of the original caster, but is otherwise '
#             'treated as if you cast the spell. The spell cast from the stone '
#             'is no longer stored in it, freeing up space.  Strength (Very '
#             'Rare). Your Strength score increases by 2, to a maximum of 20, '
#             'while this pale blue rhomboid orbits your head.  Sustenance '
#             '(Rare). You don’t need to eat or drink while this clear spindle '
#             'orbits your head. System Reference Document 5.1 228  ',
#  'location': {'chapter': 'Magic Items',
#               'section': 'Magic Items A-Z',
#               'starting_page': 227,
#               'subsection': None,
#               'subsubsection': 'Ioun Stone'}}
# {'content': 'Commune with Nature Tree Stride ',
#  'location': {'chapter': 'Spellcasting',
#               'section': 'Spell Lists',
#               'starting_page': 109,
#               'subsection': 'Ranger Spells',
#               'subsubsection': '5th Level'}}
# {'content': 'Most races have tendencies toward certain alignments, described '
#             'in this entry. These are not binding for player characters, but '
#             'considering why your dwarf is chaotic, for example, in defiance '
#             'of lawful dwarf society can help you better define your '
#             'character. ',
#  'location': {'chapter': 'Races',
#               'section': None,
#               'starting_page': 3,
#               'subsection': 'Racial Traits',
#               'subsubsection': 'Alignment'}}
# {'content': 'Wondrous item, uncommon (requires attunement) While you wear this '
#             'cloak with its hood up, Wisdom (Perception) checks made to see '
#             'you have disadvantage, and you have advantage on Dexterity '
#             '(Stealth) checks made to hide, as the cloak’s color shifts to '
#             'camouflage you. Pulling the hood up or down requires an action. ',
#  'location': {'chapter': 'Magic Items',
#               'section': 'Magic Items A-Z',
#               'starting_page': 214,
#               'subsection': None,
#               'subsubsection': 'Cloak of Elvenkind'}}
